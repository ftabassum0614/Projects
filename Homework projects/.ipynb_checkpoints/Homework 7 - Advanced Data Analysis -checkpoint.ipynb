# %% [markdown]
# ## Homework 7: Advanced Data Analysis

# %% [markdown]
# #### Exercises

# %% [markdown]
# #### The regression results tend to generate residuals that are correlated with the dependent variable. This indicates that the regression is missing an explanatory variable that better captures the magnitude of changes in RGDP. Find a variable that improves prediction of RGDP per capita. Rerun all results presented in the panel regression section with this variable included.

# %% [markdown]
# Some of you have asked if Homework 7 is due this weekend. You have learned the skills you need to complete the 1 homework problem in the assignment. If you prefer, you may run a standard OLS regression instead of a Panel OLS. The important thing is that you find another data set to include in the regression to see if the addition of the variable would help normalize the errors. If you are unable to normalize the errors, explain why you think the additional variable did not accomplish this goal.

# %%
import pandas as pd  
import numpy as np  
import datetime  
  
# import data  
data = pd.read_csv("fraserDataWithRGDPPC.csv", index_col = ["ISO_Code", "Year"],   
                   parse_dates = True)  
data["RGDP Per Capita Lag"] = data.groupby(level="ISO_Code")\
    ["RGDP Per Capita"].shift(-1)

# %%
data.index.get_level_values("Year") >= datetime.datetime(1999, 1, 1)
# Out:
# array([ True,  True,  True, ..., False, False, False])

# %%
data = data[data.index.get_level_values("Year") > datetime.datetime(1999,1,1)]
data
# Out:
#                           EFW  Size of Government  \
# ISO_Code Year
# ALB      2017-01-01  7.673511            7.528167
#          2016-01-01  7.637742            7.875862
#          2015-01-01  7.639666            7.904257
#          2014-01-01  7.586769            7.882037
#          2013-01-01  7.389525            7.807904
# ...                       ...                 ...
# ZWE      2004-01-01  3.181057            5.184469
#          2003-01-01  3.675260            5.709175
#          2002-01-01  3.625483            5.514469
#          2001-01-01  3.633489            5.547411
#          2000-01-01  4.299839            5.365058
#
#                      Legal System & Property Rights  Sound Money  \
# ISO_Code Year
# ALB      2017-01-01                        5.064907     9.648271
#          2016-01-01                        5.071814     9.553657
#          2015-01-01                        5.003489     9.585625
#          2014-01-01                        4.666740     9.629320
#          2013-01-01                        4.543782     9.690942
# ...                                             ...          ...
# ZWE      2004-01-01                        3.595709     0.000000
#          2003-01-01                        3.421352     1.250000
#          2002-01-01                        3.405224     1.250000
#          2001-01-01                        3.311100     1.702366
#          2000-01-01                        4.662445     2.891166
#
#                      Freedom to trade internationally  Regulation  \
# ISO_Code Year
# ALB      2017-01-01                          8.343863    7.782349
#          2016-01-01                          8.214900    7.472476
#          2015-01-01                          8.109118    7.595838
#          2014-01-01                          8.208630    7.547119
#          2013-01-01                          7.705771    7.199224
# ...                                               ...         ...
# ZWE      2004-01-01                          2.567670    4.557437
#          2003-01-01                          3.120167    4.875605
#          2002-01-01                          3.002611    4.955112
#          2001-01-01                          3.184783    4.421784
#          2000-01-01                          3.224735    5.355792
#
#                      RGDP Per Capita  RGDP Per Capita Lag
# ISO_Code Year
# ALB      2017-01-01              NaN              10342.0
#          2016-01-01          10342.0              10032.0
#          2015-01-01          10032.0               9808.0
#          2014-01-01           9808.0               9660.0
#          2013-01-01           9660.0               9592.0
# ...                              ...                  ...
# ZWE      2004-01-01           1622.0               1722.0
#          2003-01-01           1722.0               2054.0
#          2002-01-01           2054.0               2228.0
#          2001-01-01           2228.0               2249.0
#          2000-01-01           2249.0               2156.0
#
# [2589 rows x 8 columns]

# %%
for key in data:
    if "GDP" in key:
        data["Log " + key] = np.log(data[key])

# %%
diff_index = data.groupby(level=0).diff(-1).dropna().index  
data_dict = {}  
data_dict["Data"] = data  
data_dict["Diff Data"] = data.copy().loc[diff_index]  
data_dict["Diff Data"] = data.groupby(level=0).diff(-1)  
data_dict["Diff Data"]["North America"] = 1
data_dict["Diff Data"] = data_dict["Diff Data"].dropna()
data_dict["Data"]
# Out:
#                           EFW  Size of Government  \
# ISO_Code Year
# ALB      2017-01-01  7.673511            7.528167
#          2016-01-01  7.637742            7.875862
#          2015-01-01  7.639666            7.904257
#          2014-01-01  7.586769            7.882037
#          2013-01-01  7.389525            7.807904
# ...                       ...                 ...
# ZWE      2004-01-01  3.181057            5.184469
#          2003-01-01  3.675260            5.709175
#          2002-01-01  3.625483            5.514469
#          2001-01-01  3.633489            5.547411
#          2000-01-01  4.299839            5.365058
#
#                      Legal System & Property Rights  Sound Money  \
# ISO_Code Year
# ALB      2017-01-01                        5.064907     9.648271
#          2016-01-01                        5.071814     9.553657
#          2015-01-01                        5.003489     9.585625
#          2014-01-01                        4.666740     9.629320
#          2013-01-01                        4.543782     9.690942
# ...                                             ...          ...
# ZWE      2004-01-01                        3.595709     0.000000
#          2003-01-01                        3.421352     1.250000
#          2002-01-01                        3.405224     1.250000
#          2001-01-01                        3.311100     1.702366
#          2000-01-01                        4.662445     2.891166
#
#                      Freedom to trade internationally  Regulation  \
# ISO_Code Year
# ALB      2017-01-01                          8.343863    7.782349
#          2016-01-01                          8.214900    7.472476
#          2015-01-01                          8.109118    7.595838
#          2014-01-01                          8.208630    7.547119
#          2013-01-01                          7.705771    7.199224
# ...                                               ...         ...
# ZWE      2004-01-01                          2.567670    4.557437
#          2003-01-01                          3.120167    4.875605
#          2002-01-01                          3.002611    4.955112
#          2001-01-01                          3.184783    4.421784
#          2000-01-01                          3.224735    5.355792
#
#                      RGDP Per Capita  RGDP Per Capita Lag  \
# ISO_Code Year
# ALB      2017-01-01              NaN              10342.0
#          2016-01-01          10342.0              10032.0
#          2015-01-01          10032.0               9808.0
#          2014-01-01           9808.0               9660.0
#          2013-01-01           9660.0               9592.0
# ...                              ...                  ...
# ZWE      2004-01-01           1622.0               1722.0
#          2003-01-01           1722.0               2054.0
#          2002-01-01           2054.0               2228.0
#          2001-01-01           2228.0               2249.0
#          2000-01-01           2249.0               2156.0
#
#                      Log RGDP Per Capita  Log RGDP Per Capita Lag
# ISO_Code Year
# ALB      2017-01-01                  NaN                 9.243969
#          2016-01-01             9.243969                 9.213535
#          2015-01-01             9.213535                 9.190954
#          2014-01-01             9.190954                 9.175749
#          2013-01-01             9.175749                 9.168685
# ...                                  ...                      ...
# ZWE      2004-01-01             7.391415                 7.451242
#          2003-01-01             7.451242                 7.627544
#          2002-01-01             7.627544                 7.708860
#          2001-01-01             7.708860                 7.718241
#          2000-01-01             7.718241                 7.676010
#
# [2589 rows x 10 columns]

# %%
import pandas as pd  
import numpy as np  
import datetime  
  
def create_indicator_variable(data, indicator_name, index_name,   
                              target_index_list):  
    # Prepare column with name of indicator variable  
    data[indicator_name] = 0  
    # for each index whose name matches an entry in target_index_list  
    # a value of 1 will be recorded  
    for index in target_index_list:  
        data.loc[data.index.get_level_values(\
            index_name) == index, [indicator_name]] = 1  
        
# import data  
data = pd.read_csv("fraserDataWithRGDPPC.csv", index_col = ["ISO_Code", "Year"],   
                   parse_dates = True) 
 
data = data[data.index.get_level_values("Year") > datetime.datetime(2000,1,1)]  
keys = data.keys()
for key in keys:  
    if "GDP" in key:  
        data[key + " Lag"] = data[key].groupby("ISO_Code").shift()
        data["Log " + key] = np.log(data[key])  
        data["Log " + key + " Lag"] = data["Log " + key].groupby("ISO_Code").shift()
        
        
# so initialize the diff data as teh dataframe but only include index values  
# from a differenced matrix (one year of observations will be missing)  
diff_index = data.groupby(level=0).diff().dropna().index  
data_dict = {}  
data_dict["Data"] = data  

data_dict["Diff Data"] = data.copy().loc[diff_index]  
data_dict["Diff Data"] = data.groupby("ISO_Code").diff() 
data_dict["Diff Data"].dropna(inplace = True)  
  
# Create indicator variable for North Amierca in both data and diff_data  
indicator_name = "North America"  
index_name = "ISO_Code"  
countries_in_north_america = ["BHS", "BRB", "BLZ", "CAN", "CRI", "DOM", "SLV",  
                              "GTM", "HTI", "HND", "JAM", "MEX", "NIC", "PAN",  
                              "TTO", "USA"]  
for key in data_dict:  
    data = data_dict[key]  
    create_indicator_variable(data = data, indicator_name = indicator_name,  
        index_name = index_name,target_index_list = countries_in_north_america)

# %%
data_dict[key]
# Out:
#                           EFW  Size of Government  \
# ISO_Code Year
# ALB      2014-01-01 -0.052896           -0.022220
#          2013-01-01 -0.197245           -0.074133
#          2012-01-01 -0.057193            0.288471
#          2011-01-01  0.048732           -0.275409
#          2010-01-01 -0.000338            0.018699
# ...                       ...                 ...
# ZWE      2005-01-01 -0.123308           -0.479647
#          2004-01-01  0.291817            0.893369
#          2003-01-01  0.494203            0.524706
#          2002-01-01 -0.049776           -0.194706
#          2001-01-01  0.008006            0.032941
#
#                      Legal System & Property Rights  Sound Money  \
# ISO_Code Year
# ALB      2014-01-01                       -0.336748     0.043694
#          2013-01-01                       -0.122958     0.061623
#          2012-01-01                       -0.072290     0.019798
#          2011-01-01                        0.403390     0.064519
#          2010-01-01                        0.380981    -0.050237
# ...                                             ...          ...
# ZWE      2005-01-01                       -0.085038     0.000000
#          2004-01-01                        0.108099     0.000000
#          2003-01-01                       -0.174357     1.250000
#          2002-01-01                       -0.016127     0.000000
#          2001-01-01                       -0.094124     0.452366
#
#                      Freedom to trade internationally  Regulation  \
# ISO_Code Year
# ALB      2014-01-01                          0.099512   -0.048719
#          2013-01-01                         -0.502859   -0.347895
#          2012-01-01                         -0.590349    0.068405
#          2011-01-01                          0.003521    0.047639
#          2010-01-01                          0.127981   -0.479114
# ...                                               ...         ...
# ZWE      2005-01-01                          0.069345   -0.121200
#          2004-01-01                          0.199055    0.258565
#          2003-01-01                          0.552497    0.318168
#          2002-01-01                         -0.117556    0.079507
#          2001-01-01                          0.182173   -0.533328
#
#                      RGDP Per Capita  RGDP Per Capita Lag  \
# ISO_Code Year
# ALB      2014-01-01           -224.0               -310.0
#          2013-01-01           -148.0               -224.0
#          2012-01-01            -68.0               -148.0
#          2011-01-01           -108.0                -68.0
#          2010-01-01           -212.0               -108.0
# ...                              ...                  ...
# ZWE      2005-01-01             43.0                 36.0
#          2004-01-01            112.0                 43.0
#          2003-01-01            100.0                112.0
#          2002-01-01            332.0                100.0
#          2001-01-01            174.0                332.0
#
#                      Log RGDP Per Capita  Log RGDP Per Capita Lag  \
# ISO_Code Year
# ALB      2014-01-01            -0.022582                -0.030433
#          2013-01-01            -0.015205                -0.022582
#          2012-01-01            -0.007064                -0.015205
#          2011-01-01            -0.011323                -0.007064
#          2010-01-01            -0.022607                -0.011323
# ...                                  ...                      ...
# ZWE      2005-01-01             0.028890                 0.024846
#          2004-01-01             0.071550                 0.028890
#          2003-01-01             0.059826                 0.071550
#          2002-01-01             0.176303                 0.059826
#          2001-01-01             0.081315                 0.176303
#
#                      North America
# ISO_Code Year
# ALB      2014-01-01              0
#          2013-01-01              0
#          2012-01-01              0
#          2011-01-01              0
#          2010-01-01              0
# ...                            ...
# ZWE      2005-01-01              0
#          2004-01-01              0
#          2003-01-01              0
#          2002-01-01              0
#          2001-01-01              0
#
# [1882 rows x 11 columns]

# %%
data_dict[key].dropna()
# Out:
#                           EFW  Size of Government  \
# ISO_Code Year
# ALB      2014-01-01 -0.052896           -0.022220
#          2013-01-01 -0.197245           -0.074133
#          2012-01-01 -0.057193            0.288471
#          2011-01-01  0.048732           -0.275409
#          2010-01-01 -0.000338            0.018699
# ...                       ...                 ...
# ZWE      2005-01-01 -0.123308           -0.479647
#          2004-01-01  0.291817            0.893369
#          2003-01-01  0.494203            0.524706
#          2002-01-01 -0.049776           -0.194706
#          2001-01-01  0.008006            0.032941
#
#                      Legal System & Property Rights  Sound Money  \
# ISO_Code Year
# ALB      2014-01-01                       -0.336748     0.043694
#          2013-01-01                       -0.122958     0.061623
#          2012-01-01                       -0.072290     0.019798
#          2011-01-01                        0.403390     0.064519
#          2010-01-01                        0.380981    -0.050237
# ...                                             ...          ...
# ZWE      2005-01-01                       -0.085038     0.000000
#          2004-01-01                        0.108099     0.000000
#          2003-01-01                       -0.174357     1.250000
#          2002-01-01                       -0.016127     0.000000
#          2001-01-01                       -0.094124     0.452366
#
#                      Freedom to trade internationally  Regulation  \
# ISO_Code Year
# ALB      2014-01-01                          0.099512   -0.048719
#          2013-01-01                         -0.502859   -0.347895
#          2012-01-01                         -0.590349    0.068405
#          2011-01-01                          0.003521    0.047639
#          2010-01-01                          0.127981   -0.479114
# ...                                               ...         ...
# ZWE      2005-01-01                          0.069345   -0.121200
#          2004-01-01                          0.199055    0.258565
#          2003-01-01                          0.552497    0.318168
#          2002-01-01                         -0.117556    0.079507
#          2001-01-01                          0.182173   -0.533328
#
#                      RGDP Per Capita  RGDP Per Capita Lag  \
# ISO_Code Year
# ALB      2014-01-01           -224.0               -310.0
#          2013-01-01           -148.0               -224.0
#          2012-01-01            -68.0               -148.0
#          2011-01-01           -108.0                -68.0
#          2010-01-01           -212.0               -108.0
# ...                              ...                  ...
# ZWE      2005-01-01             43.0                 36.0
#          2004-01-01            112.0                 43.0
#          2003-01-01            100.0                112.0
#          2002-01-01            332.0                100.0
#          2001-01-01            174.0                332.0
#
#                      Log RGDP Per Capita  Log RGDP Per Capita Lag  \
# ISO_Code Year
# ALB      2014-01-01            -0.022582                -0.030433
#          2013-01-01            -0.015205                -0.022582
#          2012-01-01            -0.007064                -0.015205
#          2011-01-01            -0.011323                -0.007064
#          2010-01-01            -0.022607                -0.011323
# ...                                  ...                      ...
# ZWE      2005-01-01             0.028890                 0.024846
#          2004-01-01             0.071550                 0.028890
#          2003-01-01             0.059826                 0.071550
#          2002-01-01             0.176303                 0.059826
#          2001-01-01             0.081315                 0.176303
#
#                      North America
# ISO_Code Year
# ALB      2014-01-01              0
#          2013-01-01              0
#          2012-01-01              0
#          2011-01-01              0
#          2010-01-01              0
# ...                            ...
# ZWE      2005-01-01              0
#          2004-01-01              0
#          2003-01-01              0
#          2002-01-01              0
#          2001-01-01              0
#
# [1882 rows x 11 columns]

# %% [markdown]
# ## Initial Regression

# %%
import statsmodels.api as sm
# . . . 
# prepare regression variables  
X_names = ["EFW", "Log RGDP Per Capita Lag"]  
y_name = ["Log RGDP Per Capita"]  

# save instance of regression class  
for key in data_dict:  
    reg_data = data_dict[key].dropna()
    X = reg_data[X_names]
    X["Constant"] = 1
    Y = reg_data[y_name]    # call OLS method  
    print(key)
    data = data_dict[key]  
    results = sm.OLS(Y, X).fit()  
    print(results.summary())
# Out:
# Data
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     Log RGDP Per Capita   R-squared:                       0.999
# Model:                             OLS   Adj. R-squared:                  0.999
# Method:                  Least Squares   F-statistic:                 8.073e+05
# Date:                 Wed, 01 Dec 2021   Prob (F-statistic):               0.00
# Time:                         07:39:33   Log-Likelihood:                 3475.9
# No. Observations:                 2031   AIC:                            -6946.
# Df Residuals:                     2028   BIC:                            -6929.
# Df Model:                            2
# Covariance Type:             nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# EFW                        -0.0042      0.001     -3.152      0.002      -0.007      -0.002
# Log RGDP Per Capita Lag     1.0049      0.001    955.589      0.000       1.003       1.007
# Constant                   -0.0388      0.008     -4.976      0.000      -0.054      -0.023
# ==============================================================================
# Omnibus:                     1005.266   Durbin-Watson:                   1.202
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            27771.877
# Skew:                           1.754   Prob(JB):                         0.00
# Kurtosis:                      20.773   Cond. No.                         93.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Diff Data
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     Log RGDP Per Capita   R-squared:                       0.203
# Model:                             OLS   Adj. R-squared:                  0.202
# Method:                  Least Squares   F-statistic:                     239.0
# Date:                 Wed, 01 Dec 2021   Prob (F-statistic):           3.27e-93
# Time:                         07:39:33   Log-Likelihood:                 3408.4
# No. Observations:                 1882   AIC:                            -6811.
# Df Residuals:                     1879   BIC:                            -6794.
# Df Model:                            2
# Covariance Type:             nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# EFW                         0.0228      0.005      4.173      0.000       0.012       0.033
# Log RGDP Per Capita Lag     0.4447      0.022     20.476      0.000       0.402       0.487
# Constant                   -0.0127      0.001    -12.372      0.000      -0.015      -0.011
# ==============================================================================
# Omnibus:                     1036.952   Durbin-Watson:                   2.052
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            36332.806
# Skew:                           1.967   Prob(JB):                         0.00
# Kurtosis:                      24.162   Cond. No.                         23.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\faria\AppData\Local\Temp/ipykernel_16284/1966889043.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Constant"] = 1
# C:\Users\faria\AppData\Local\Temp/ipykernel_16284/1966889043.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Constant"] = 1

# %% [markdown]
# ## Adding the North America Variable

# %%
X_names = ["EFW", "Log RGDP Per Capita Lag", "North America"]
# . . .
for key in data_dict:  
    reg_data = data_dict[key].dropna()
    X = reg_data[X_names]
    X["Constant"] = 1
    Y = reg_data[y_name]    # call OLS method  
    print(key)
    data = data_dict[key]  
    results = sm.OLS(Y, X).fit()  
    print(results.summary())
# Out:
# Data
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     Log RGDP Per Capita   R-squared:                       0.999
# Model:                             OLS   Adj. R-squared:                  0.999
# Method:                  Least Squares   F-statistic:                 5.385e+05
# Date:                 Wed, 01 Dec 2021   Prob (F-statistic):               0.00
# Time:                         07:39:49   Log-Likelihood:                 3477.0
# No. Observations:                 2031   AIC:                            -6946.
# Df Residuals:                     2027   BIC:                            -6923.
# Df Model:                            3
# Covariance Type:             nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# EFW                        -0.0046      0.001     -3.374      0.001      -0.007      -0.002
# Log RGDP Per Capita Lag     1.0051      0.001    949.380      0.000       1.003       1.007
# North America               0.0049      0.003      1.449      0.148      -0.002       0.011
# Constant                   -0.0383      0.008     -4.912      0.000      -0.054      -0.023
# ==============================================================================
# Omnibus:                     1009.789   Durbin-Watson:                   1.204
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            28090.248
# Skew:                           1.763   Prob(JB):                         0.00
# Kurtosis:                      20.875   Cond. No.                         93.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Diff Data
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     Log RGDP Per Capita   R-squared:                       0.203
# Model:                             OLS   Adj. R-squared:                  0.202
# Method:                  Least Squares   F-statistic:                     159.4
# Date:                 Wed, 01 Dec 2021   Prob (F-statistic):           4.62e-92
# Time:                         07:39:49   Log-Likelihood:                 3408.6
# No. Observations:                 1882   AIC:                            -6809.
# Df Residuals:                     1878   BIC:                            -6787.
# Df Model:                            3
# Covariance Type:             nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# EFW                         0.0227      0.005      4.156      0.000       0.012       0.033
# Log RGDP Per Capita Lag     0.4445      0.022     20.463      0.000       0.402       0.487
# North America               0.0020      0.003      0.652      0.514      -0.004       0.008
# Constant                   -0.0129      0.001    -12.038      0.000      -0.015      -0.011
# ==============================================================================
# Omnibus:                     1040.521   Durbin-Watson:                   2.052
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            36503.868
# Skew:                           1.977   Prob(JB):                         0.00
# Kurtosis:                      24.210   Cond. No.                         24.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\faria\AppData\Local\Temp/ipykernel_16284/1084523375.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Constant"] = 1
# C:\Users\faria\AppData\Local\Temp/ipykernel_16284/1084523375.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Constant"] = 1

# %%
import linearmodels

# %%
import matplotlib.pyplot as plt
from linearmodels import PanelOLS
# . . . .
y_name = ["Log RGDP Per Capita"]
X_names = ["Size of Government", 
          "Legal System & Property Rights", 
          "Sound Money",
          "Freedom to trade internationally",
          "Regulation"]
for key, data in data_dict.items():
    for entity in [True, False]:
        for time in [True, False]:
            print(key)
            print("Entity =", entity)
            print("Time =", time)
            reg_data = data_dict[key].dropna()
            Y = reg_data[y_name]
            X = reg_data[X_names]
            X["Constant"] = 1
            # call panel_regression method        
            model = PanelOLS(Y,X, entity_effects=entity, time_effects=time)
            results = model.fit(cov_type='clustered', cluster_entity=True)
            print(key, results, sep ="\n") 
            reg_data["Predictor"] = results.predict()
            reg_data["Residuals"] = reg_data[y_name[0]].sub(reg_data["Predictor"])

            # plot distribution of residuals
            fig, ax = plt.subplots(figsize = (12,8))
            reg_data[["Residuals"]].plot.hist(bins = 100, ax = ax)
            plt.title(key + "\nEntity = " + str(entity) + " Time = " + str(time) )

            # plot observed vs. predicted values
            fig, ax = plt.subplots(figsize = (14,10))
            reg_data.plot.scatter(x = y_name[0],
                             y = "Predictor", 
                              s = 30, ax = ax)
            plt.xticks(rotation=90)
            plt.title(key + "\nEntity = " + str(entity) + " Time = " + str(time) )
            plt.show()
            plt.close()

            # plot observed against residuals
            fig, ax = plt.subplots(figsize = (14,10))
            reg_data.plot.scatter(x = y_name[0],
                             y = "Residuals", 
                              s = 30, ax = ax)
            ax.axhline(0, ls = "--", color = "k")
            plt.xticks(rotation=90)
            plt.title(key + "\nEntity = " + str(entity) + " Time = " + str(time) )
            plt.show()
            plt.close()
# Out:
# Data
# Entity = True
# Time = True
# Data
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     Log RGDP Per Capita   R-squared:                        0.0708
# Estimator:                    PanelOLS   R-squared (Between):              0.1185
# No. Observations:                 2031   R-squared (Within):               0.1328
# Date:                 Wed, Dec 01 2021   R-squared (Overall):              0.1279
# Time:                         07:42:17   Log-likelihood                    1908.3
# Cov. Estimator:              Clustered
#                                          F-statistic:                      28.386
# Entities:                          162   P-value                           0.0000
# Avg Obs:                        12.537   Distribution:                  F(5,1863)
# Min Obs:                        0.0000
# Max Obs:                        15.000   F-statistic (robust):             3.9664
#                                          P-value                           0.0014
# Time periods:                       22   Distribution:                  F(5,1863)
# Avg Obs:                        92.318
# Min Obs:                        0.0000
# Max Obs:                        149.00
#
#                                         Parameter Estimates
# ====================================================================================================
#                                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------------------
# Size of Government                   0.0127     0.0124     1.0188     0.3084     -0.0117      0.0370
# Legal System & Property Rights       0.0349     0.0148     2.3506     0.0188      0.0058      0.0639
# Sound Money                          0.0181     0.0104     1.7470     0.0808     -0.0022      0.0384
# Freedom to trade internationally     0.0156     0.0171     0.9115     0.3621     -0.0179      0.0491
# Regulation                           0.0303     0.0156     1.9381     0.0528     -0.0004      0.0609
# Constant                             8.4372     0.1948     43.316     0.0000      8.0552      8.8192
# ====================================================================================================
#
# F-test for Poolability: 743.21
# P-value: 0.0000
# Distribution: F(162,1863)
#
# Included effects: Entity, Time
# C:\Users\faria\AppData\Local\Temp/ipykernel_16284/2640814865.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Constant"] = 1
# C:\Users\faria\anaconda3\lib\site-packages\linearmodels\panel\results.py:544: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   out_df: DataFrame = concat(out, 1)
# C:\Users\faria\AppData\Local\Temp/ipykernel_16284/2640814865.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reg_data["Predictor"] = results.predict()
# C:\Users\faria\AppData\Local\Temp/ipykernel_16284/2640814865.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reg_data["Residuals"] = reg_data[y_name[0]].sub(reg_data["Predictor"])
# Data
# Entity = True
# Time = False
# Data
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     Log RGDP Per Capita   R-squared:                        0.2108
# Estimator:                    PanelOLS   R-squared (Between):              0.2018
# No. Observations:                 2031   R-squared (Within):               0.2108
# Date:                 Wed, Dec 01 2021   R-squared (Overall):              0.2179
# Time:                         07:42:18   Log-likelihood                    1397.6
# Cov. Estimator:              Clustered
#                                          F-statistic:                      100.26
# Entities:                          162   P-value                           0.0000
# Avg Obs:                        12.537   Distribution:                  F(5,1877)
# Min Obs:                        0.0000
# Max Obs:                        15.000   F-statistic (robust):             17.657
#                                          P-value                           0.0000
# Time periods:                       22   Distribution:                  F(5,1877)
# Avg Obs:                        92.318
# Min Obs:                        0.0000
# Max Obs:                        149.00
#
#                                         Parameter Estimates
# ====================================================================================================
#                                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------------------
# Size of Government                   0.0083     0.0146     0.5685     0.5698     -0.0203      0.0368
# Legal System & Property Rights       0.0550     0.0176     3.1283     0.0018      0.0205      0.0894
# Sound Money                          0.0401     0.0106     3.7939     0.0002      0.0194      0.0609
# Freedom to trade internationally    -0.0102     0.0187    -0.5466     0.5847     -0.0469      0.0265
# Regulation                           0.1118     0.0178     6.2695     0.0000      0.0768      0.1468
# Constant                             7.8070     0.2546     30.667     0.0000      7.3077      8.3063
# ====================================================================================================
#
# F-test for Poolability: 490.65
# P-value: 0.0000
# Distribution: F(148,1877)
#
# Included effects: Entity
# C:\Users\faria\AppData\Local\Temp/ipykernel_16284/2640814865.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Constant"] = 1
# Data
# Entity = False
# Time = True
# Data
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     Log RGDP Per Capita   R-squared:                        0.6156
# Estimator:                    PanelOLS   R-squared (Between):              0.6172
# No. Observations:                 2031   R-squared (Within):              -1.5357
# Date:                 Wed, Dec 01 2021   R-squared (Overall):              0.6145
# Time:                         07:42:18   Log-likelihood                   -2335.4
# Cov. Estimator:              Clustered
#                                          F-statistic:                      643.99
# Entities:                          162   P-value                           0.0000
# Avg Obs:                        12.537   Distribution:                  F(5,2011)
# Min Obs:                        0.0000
# Max Obs:                        15.000   F-statistic (robust):             81.798
#                                          P-value                           0.0000
# Time periods:                       22   Distribution:                  F(5,2011)
# Avg Obs:                        92.318
# Min Obs:                        0.0000
# Max Obs:                        149.00
#
#                                         Parameter Estimates
# ====================================================================================================
#                                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------------------
# Size of Government                  -0.1871     0.0516    -3.6263     0.0003     -0.2882     -0.0859
# Legal System & Property Rights       0.3521     0.0511     6.8929     0.0000      0.2519      0.4523
# Sound Money                          0.0484     0.0565     0.8564     0.3919     -0.0624      0.1591
# Freedom to trade internationally     0.3050     0.0903     3.3787     0.0007      0.1280      0.4821
# Regulation                           0.0064     0.0896     0.0718     0.9428     -0.1692      0.1821
# Constant                             5.9292     0.6837     8.6717     0.0000      4.5883      7.2701
# ====================================================================================================
#
# F-test for Poolability: 0.7320
# P-value: 0.7435
# Distribution: F(14,2011)
#
# Included effects: Time
# C:\Users\faria\anaconda3\lib\site-packages\linearmodels\panel\results.py:544: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   out_df: DataFrame = concat(out, 1)
# C:\Users\faria\AppData\Local\Temp/ipykernel_16284/2640814865.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reg_data["Predictor"] = results.predict()
# C:\Users\faria\AppData\Local\Temp/ipykernel_16284/2640814865.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reg_data["Residuals"] = reg_data[y_name[0]].sub(reg_data["Predictor"])
# Data
# Entity = False
# Time = False
# Data
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     Log RGDP Per Capita   R-squared:                        0.6146
# Estimator:                    PanelOLS   R-squared (Between):              0.6167
# No. Observations:                 2031   R-squared (Within):              -1.4914
# Date:                 Wed, Dec 01 2021   R-squared (Overall):              0.6146
# Time:                         07:42:19   Log-likelihood                   -2340.5
# Cov. Estimator:              Clustered
#                                          F-statistic:                      645.80
# Entities:                          162   P-value                           0.0000
# Avg Obs:                        12.537   Distribution:                  F(5,2025)
# Min Obs:                        0.0000
# Max Obs:                        15.000   F-statistic (robust):             81.048
#                                          P-value                           0.0000
# Time periods:                       22   Distribution:                  F(5,2025)
# Avg Obs:                        92.318
# Min Obs:                        0.0000
# Max Obs:                        149.00
#
#                                         Parameter Estimates
# ====================================================================================================
#                                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------------------
# Size of Government                  -0.1893     0.0505    -3.7470     0.0002     -0.2883     -0.0902
# Legal System & Property Rights       0.3475     0.0497     6.9893     0.0000      0.2500      0.4450
# Sound Money                          0.0559     0.0556     1.0053     0.3149     -0.0532      0.1650
# Freedom to trade internationally     0.2935     0.0885     3.3156     0.0009      0.1199      0.4671
# Regulation                           0.0207     0.0847     0.2443     0.8070     -0.1454      0.1867
# Constant                             5.8916     0.6771     8.7009     0.0000      4.5636      7.2195
# ====================================================================================================
# C:\Users\faria\AppData\Local\Temp/ipykernel_16284/2640814865.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Constant"] = 1
# Diff Data
# Entity = True
# Time = True
# Diff Data
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     Log RGDP Per Capita   R-squared:                        0.0192
# Estimator:                    PanelOLS   R-squared (Between):              0.0021
# No. Observations:                 1882   R-squared (Within):               0.0177
# Date:                 Wed, Dec 01 2021   R-squared (Overall):              0.0198
# Time:                         07:42:20   Log-likelihood                    3701.2
# Cov. Estimator:              Clustered
#                                          F-statistic:                      6.7241
# Entities:                          162   P-value                           0.0000
# Avg Obs:                        11.617   Distribution:                  F(5,1715)
# Min Obs:                        0.0000
# Max Obs:                        14.000   F-statistic (robust):             3.6843
#                                          P-value                           0.0025
# Time periods:                       21   Distribution:                  F(5,1715)
# Avg Obs:                        89.619
# Min Obs:                        0.0000
# Max Obs:                        149.00
#
#                                         Parameter Estimates
# ====================================================================================================
#                                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------------------
# Size of Government                  -0.0012     0.0053    -0.2328     0.8160     -0.0116      0.0091
# Legal System & Property Rights       0.0091     0.0053     1.7083     0.0878     -0.0013      0.0195
# Sound Money                          0.0081     0.0028     2.9085     0.0037      0.0026      0.0135
# Freedom to trade internationally     0.0050     0.0044     1.1417     0.2537     -0.0036      0.0137
# Regulation                           0.0027     0.0032     0.8458     0.3978     -0.0036      0.0091
# Constant                            -0.0223     0.0002    -143.71     0.0000     -0.0226     -0.0220
# ====================================================================================================
#
# F-test for Poolability: 7.0936
# P-value: 0.0000
# Distribution: F(161,1715)
#
# Included effects: Entity, Time
# C:\Users\faria\anaconda3\lib\site-packages\linearmodels\panel\results.py:544: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   out_df: DataFrame = concat(out, 1)
# Diff Data
# Entity = True
# Time = False
# Diff Data
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     Log RGDP Per Capita   R-squared:                        0.0232
# Estimator:                    PanelOLS   R-squared (Between):              0.0127
# No. Observations:                 1882   R-squared (Within):               0.0232
# Date:                 Wed, Dec 01 2021   R-squared (Overall):              0.0255
# Time:                         07:42:20   Log-likelihood                    3531.4
# Cov. Estimator:              Clustered
#                                          F-statistic:                      8.2208
# Entities:                          162   P-value                           0.0000
# Avg Obs:                        11.617   Distribution:                  F(5,1728)
# Min Obs:                        0.0000
# Max Obs:                        14.000   F-statistic (robust):             4.5663
#                                          P-value                           0.0004
# Time periods:                       21   Distribution:                  F(5,1728)
# Avg Obs:                        89.619
# Min Obs:                        0.0000
# Max Obs:                        149.00
#
#                                         Parameter Estimates
# ====================================================================================================
#                                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------------------
# Size of Government                   0.0047     0.0053     0.8903     0.3734     -0.0057      0.0152
# Legal System & Property Rights       0.0142     0.0046     3.0580     0.0023      0.0051      0.0233
# Sound Money                          0.0059     0.0028     2.0985     0.0360      0.0004      0.0115
# Freedom to trade internationally     0.0054     0.0043     1.2477     0.2123     -0.0031      0.0139
# Regulation                           0.0039     0.0030     1.3019     0.1931     -0.0020      0.0098
# Constant                            -0.0222     0.0002    -146.06     0.0000     -0.0225     -0.0219
# ====================================================================================================
#
# F-test for Poolability: 4.5629
# P-value: 0.0000
# Distribution: F(148,1728)
#
# Included effects: Entity
# C:\Users\faria\AppData\Local\Temp/ipykernel_16284/2640814865.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Constant"] = 1
# Diff Data
# Entity = False
# Time = True
# Diff Data
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     Log RGDP Per Capita   R-squared:                        0.0231
# Estimator:                    PanelOLS   R-squared (Between):              0.0161
# No. Observations:                 1882   R-squared (Within):               0.0184
# Date:                 Wed, Dec 01 2021   R-squared (Overall):              0.0236
# Time:                         07:42:21   Log-likelihood                    3339.5
# Cov. Estimator:              Clustered
#                                          F-statistic:                      8.8245
# Entities:                          162   P-value                           0.0000
# Avg Obs:                        11.617   Distribution:                  F(5,1863)
# Min Obs:                        0.0000
# Max Obs:                        14.000   F-statistic (robust):             5.2181
#                                          P-value                           0.0001
# Time periods:                       21   Distribution:                  F(5,1863)
# Avg Obs:                        89.619
# Min Obs:                        0.0000
# Max Obs:                        149.00
#
#                                         Parameter Estimates
# ====================================================================================================
#                                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------------------
# Size of Government                   0.0001     0.0052     0.0199     0.9841     -0.0101      0.0103
# Legal System & Property Rights       0.0101     0.0053     1.9114     0.0561     -0.0003      0.0206
# Sound Money                          0.0089     0.0031     2.8441     0.0045      0.0028      0.0151
# Freedom to trade internationally     0.0087     0.0047     1.8293     0.0675     -0.0006      0.0179
# Regulation                           0.0064     0.0033     1.9407     0.0524   -6.82e-05      0.0129
# Constant                            -0.0221     0.0018    -12.259     0.0000     -0.0256     -0.0186
# ====================================================================================================
#
# F-test for Poolability: 19.247
# P-value: 0.0000
# Distribution: F(13,1863)
#
# Included effects: Time
# C:\Users\faria\anaconda3\lib\site-packages\linearmodels\panel\results.py:544: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   out_df: DataFrame = concat(out, 1)
# Diff Data
# Entity = False
# Time = False
# Diff Data
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     Log RGDP Per Capita   R-squared:                        0.0271
# Estimator:                    PanelOLS   R-squared (Between):              0.0262
# No. Observations:                 1882   R-squared (Within):               0.0212
# Date:                 Wed, Dec 01 2021   R-squared (Overall):              0.0271
# Time:                         07:42:21   Log-likelihood                    3220.9
# Cov. Estimator:              Clustered
#                                          F-statistic:                      10.447
# Entities:                          162   P-value                           0.0000
# Avg Obs:                        11.617   Distribution:                  F(5,1876)
# Min Obs:                        0.0000
# Max Obs:                        14.000   F-statistic (robust):             5.5443
#                                          P-value                           0.0000
# Time periods:                       21   Distribution:                  F(5,1876)
# Avg Obs:                        89.619
# Min Obs:                        0.0000
# Max Obs:                        149.00
#
#                                         Parameter Estimates
# ====================================================================================================
#                                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------------------
# Size of Government                   0.0055     0.0054     1.0277     0.3042     -0.0050      0.0161
# Legal System & Property Rights       0.0148     0.0050     2.9629     0.0031      0.0050      0.0247
# Sound Money                          0.0067     0.0032     2.1226     0.0339      0.0005      0.0129
# Freedom to trade internationally     0.0093     0.0048     1.9343     0.0532     -0.0001      0.0186
# Regulation                           0.0075     0.0032     2.3304     0.0199      0.0012      0.0138
# Constant                            -0.0220     0.0018    -12.302     0.0000     -0.0256     -0.0185
# ====================================================================================================
# C:\Users\faria\AppData\Local\Temp/ipykernel_16284/2640814865.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Constant"] = 1

# %% [markdown]
# ## Running a regression without a constant term

# %%
import matplotlib.pyplot as plt
from linearmodels import PanelOLS
# . . . .
y_name = ["Log RGDP Per Capita"]
X_names = [#"Log RGDP Per Capita Lag",
          "Size of Government", 
          "Legal System & Property Rights", 
          "Sound Money",
          "Freedom to trade internationally",
          "Regulation"]
for key, data in data_dict.items():
    for entity in [True, False]:
        for time in [True, False]:
            print(key)
            print("Entity =", entity)
            print("Time =", time)
            reg_data = data_dict[key].dropna()
            Y = reg_data[y_name]
            X = reg_data[X_names]
            #X["Constant"] = 1
            # call panel_regression method        
            model = PanelOLS(Y,X, entity_effects=entity, time_effects=time)
            results = model.fit(cov_type='clustered', cluster_entity=True)
            print(key, results, sep ="\n") 
            reg_data["Predictor"] = results.predict()
            reg_data["Residuals"] = reg_data[y_name[0]].sub(reg_data["Predictor"])

            # plot distribution of residuals
            fig, ax = plt.subplots(figsize = (12,8))
            reg_data[["Residuals"]].plot.hist(bins = 100, ax = ax)
            plt.title(key + "\nEntity = " + str(entity) + " Time = " + str(time) )

            # plot observed vs. predicted values
            fig, ax = plt.subplots(figsize = (14,10))
            reg_data.plot.scatter(x = y_name[0],
                             y = "Predictor", 
                              s = 30, ax = ax)
            plt.xticks(rotation=90)
            plt.title(key + "\nEntity = " + str(entity) + " Time = " + str(time) )
            plt.show()
            plt.close()

            # plot observed against residuals
            fig, ax = plt.subplots(figsize = (14,10))
            reg_data.plot.scatter(x = y_name[0],
                             y = "Residuals", 
                              s = 30, ax = ax)
            ax.axhline(0, ls = "--", color = "k")
            plt.xticks(rotation=90)
            plt.title(key + "\nEntity = " + str(entity) + " Time = " + str(time) )
            plt.show()
            plt.close()
# Out:
# Data
# Entity = True
# Time = True
# Data
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     Log RGDP Per Capita   R-squared:                        0.0708
# Estimator:                    PanelOLS   R-squared (Between):              0.1525
# No. Observations:                 2031   R-squared (Within):               0.1328
# Date:                 Wed, Dec 01 2021   R-squared (Overall):              0.1526
# Time:                         07:43:40   Log-likelihood                    1908.3
# Cov. Estimator:              Clustered
#                                          F-statistic:                      28.386
# Entities:                          162   P-value                           0.0000
# Avg Obs:                        12.537   Distribution:                  F(5,1863)
# Min Obs:                        0.0000
# Max Obs:                        15.000   F-statistic (robust):             3.9664
#                                          P-value                           0.0014
# Time periods:                       22   Distribution:                  F(5,1863)
# Avg Obs:                        92.318
# Min Obs:                        0.0000
# Max Obs:                        149.00
#
#                                         Parameter Estimates
# ====================================================================================================
#                                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------------------
# Size of Government                   0.0127     0.0124     1.0188     0.3084     -0.0117      0.0370
# Legal System & Property Rights       0.0349     0.0148     2.3506     0.0188      0.0058      0.0639
# Sound Money                          0.0181     0.0104     1.7470     0.0808     -0.0022      0.0384
# Freedom to trade internationally     0.0156     0.0171     0.9115     0.3621     -0.0179      0.0491
# Regulation                           0.0303     0.0156     1.9381     0.0528     -0.0004      0.0609
# ====================================================================================================
#
# F-test for Poolability: 743.21
# P-value: 0.0000
# Distribution: F(162,1863)
#
# Included effects: Entity, Time
# C:\Users\faria\anaconda3\lib\site-packages\linearmodels\panel\results.py:544: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   out_df: DataFrame = concat(out, 1)
# C:\Users\faria\AppData\Local\Temp/ipykernel_16284/1384843114.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reg_data["Predictor"] = results.predict()
# C:\Users\faria\AppData\Local\Temp/ipykernel_16284/1384843114.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reg_data["Residuals"] = reg_data[y_name[0]].sub(reg_data["Predictor"])
# Data
# Entity = True
# Time = False
# Data
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     Log RGDP Per Capita   R-squared:                        0.2108
# Estimator:                    PanelOLS   R-squared (Between):              0.2741
# No. Observations:                 2031   R-squared (Within):               0.2108
# Date:                 Wed, Dec 01 2021   R-squared (Overall):              0.2738
# Time:                         07:43:41   Log-likelihood                    1397.6
# Cov. Estimator:              Clustered
#                                          F-statistic:                      100.26
# Entities:                          162   P-value                           0.0000
# Avg Obs:                        12.537   Distribution:                  F(5,1877)
# Min Obs:                        0.0000
# Max Obs:                        15.000   F-statistic (robust):             17.665
#                                          P-value                           0.0000
# Time periods:                       22   Distribution:                  F(5,1877)
# Avg Obs:                        92.318
# Min Obs:                        0.0000
# Max Obs:                        149.00
#
#                                         Parameter Estimates
# ====================================================================================================
#                                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------------------
# Size of Government                   0.0083     0.0146     0.5686     0.5697     -0.0203      0.0368
# Legal System & Property Rights       0.0550     0.0176     3.1290     0.0018      0.0205      0.0894
# Sound Money                          0.0401     0.0106     3.7948     0.0002      0.0194      0.0609
# Freedom to trade internationally    -0.0102     0.0187    -0.5467     0.5846     -0.0469      0.0265
# Regulation                           0.1118     0.0178     6.2710     0.0000      0.0768      0.1467
# ====================================================================================================
#
# F-test for Poolability: 490.65
# P-value: 0.0000
# Distribution: F(148,1877)
#
# Included effects: Entity
# Data
# Entity = False
# Time = True
# Data
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     Log RGDP Per Capita   R-squared:                        0.6156
# Estimator:                    PanelOLS   R-squared (Between):              0.5805
# No. Observations:                 2031   R-squared (Within):              -1.5357
# Date:                 Wed, Dec 01 2021   R-squared (Overall):              0.5823
# Time:                         07:43:41   Log-likelihood                   -2335.4
# Cov. Estimator:              Clustered
#                                          F-statistic:                      643.99
# Entities:                          162   P-value                           0.0000
# Avg Obs:                        12.537   Distribution:                  F(5,2011)
# Min Obs:                        0.0000
# Max Obs:                        15.000   F-statistic (robust):             81.798
#                                          P-value                           0.0000
# Time periods:                       22   Distribution:                  F(5,2011)
# Avg Obs:                        92.318
# Min Obs:                        0.0000
# Max Obs:                        149.00
#
#                                         Parameter Estimates
# ====================================================================================================
#                                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------------------
# Size of Government                  -0.1871     0.0516    -3.6263     0.0003     -0.2882     -0.0859
# Legal System & Property Rights       0.3521     0.0511     6.8929     0.0000      0.2519      0.4523
# Sound Money                          0.0484     0.0565     0.8564     0.3919     -0.0624      0.1591
# Freedom to trade internationally     0.3050     0.0903     3.3787     0.0007      0.1280      0.4821
# Regulation                           0.0064     0.0896     0.0718     0.9428     -0.1692      0.1821
# ====================================================================================================
#
# F-test for Poolability: 0.7320
# P-value: 0.7435
# Distribution: F(14,2011)
#
# Included effects: Time
# C:\Users\faria\anaconda3\lib\site-packages\linearmodels\panel\results.py:544: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   out_df: DataFrame = concat(out, 1)
# C:\Users\faria\AppData\Local\Temp/ipykernel_16284/1384843114.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reg_data["Predictor"] = results.predict()
# C:\Users\faria\AppData\Local\Temp/ipykernel_16284/1384843114.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reg_data["Residuals"] = reg_data[y_name[0]].sub(reg_data["Predictor"])
# Data
# Entity = False
# Time = False
# Data
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     Log RGDP Per Capita   R-squared:                        0.9879
# Estimator:                    PanelOLS   R-squared (Between):              0.9885
# No. Observations:                 2031   R-squared (Within):              -4.3204
# Date:                 Wed, Dec 01 2021   R-squared (Overall):              0.9879
# Time:                         07:43:42   Log-likelihood                   -2915.1
# Cov. Estimator:              Clustered
#                                          F-statistic:                   3.315e+04
# Entities:                          162   P-value                           0.0000
# Avg Obs:                        12.537   Distribution:                  F(5,2026)
# Min Obs:                        0.0000
# Max Obs:                        15.000   F-statistic (robust):             4049.8
#                                          P-value                           0.0000
# Time periods:                       22   Distribution:                  F(5,2026)
# Avg Obs:                        92.318
# Min Obs:                        0.0000
# Max Obs:                        149.00
#
#                                         Parameter Estimates
# ====================================================================================================
#                                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------------------
# Size of Government                   0.1314     0.0687     1.9110     0.0561     -0.0034      0.2662
# Legal System & Property Rights       0.2689     0.0664     4.0510     0.0001      0.1387      0.3990
# Sound Money                          0.1043     0.0872     1.1964     0.2317     -0.0667      0.2753
# Freedom to trade internationally     0.4476     0.1121     3.9925     0.0001      0.2278      0.6675
# Regulation                           0.4079     0.0934     4.3688     0.0000      0.2248      0.5910
# ====================================================================================================
# Diff Data
# Entity = True
# Time = True
# Diff Data
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     Log RGDP Per Capita   R-squared:                        0.0192
# Estimator:                    PanelOLS   R-squared (Between):              0.0220
# No. Observations:                 1882   R-squared (Within):               0.0177
# Date:                 Wed, Dec 01 2021   R-squared (Overall):              0.0265
# Time:                         07:43:42   Log-likelihood                    3701.2
# Cov. Estimator:              Clustered
#                                          F-statistic:                      6.7241
# Entities:                          162   P-value                           0.0000
# Avg Obs:                        11.617   Distribution:                  F(5,1715)
# Min Obs:                        0.0000
# Max Obs:                        14.000   F-statistic (robust):             3.6843
#                                          P-value                           0.0025
# Time periods:                       21   Distribution:                  F(5,1715)
# Avg Obs:                        89.619
# Min Obs:                        0.0000
# Max Obs:                        149.00
#
#                                         Parameter Estimates
# ====================================================================================================
#                                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------------------
# Size of Government                  -0.0012     0.0053    -0.2328     0.8160     -0.0116      0.0091
# Legal System & Property Rights       0.0091     0.0053     1.7083     0.0878     -0.0013      0.0195
# Sound Money                          0.0081     0.0028     2.9085     0.0037      0.0026      0.0135
# Freedom to trade internationally     0.0050     0.0044     1.1417     0.2537     -0.0036      0.0137
# Regulation                           0.0027     0.0032     0.8458     0.3978     -0.0036      0.0091
# ====================================================================================================
#
# F-test for Poolability: 7.0936
# P-value: 0.0000
# Distribution: F(161,1715)
#
# Included effects: Entity, Time
# C:\Users\faria\anaconda3\lib\site-packages\linearmodels\panel\results.py:544: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   out_df: DataFrame = concat(out, 1)
# Diff Data
# Entity = True
# Time = False
# Diff Data
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     Log RGDP Per Capita   R-squared:                        0.0232
# Estimator:                    PanelOLS   R-squared (Between):              0.0306
# No. Observations:                 1882   R-squared (Within):               0.0232
# Date:                 Wed, Dec 01 2021   R-squared (Overall):              0.0325
# Time:                         07:43:43   Log-likelihood                    3531.4
# Cov. Estimator:              Clustered
#                                          F-statistic:                      8.2208
# Entities:                          162   P-value                           0.0000
# Avg Obs:                        11.617   Distribution:                  F(5,1728)
# Min Obs:                        0.0000
# Max Obs:                        14.000   F-statistic (robust):             4.5687
#                                          P-value                           0.0004
# Time periods:                       21   Distribution:                  F(5,1728)
# Avg Obs:                        89.619
# Min Obs:                        0.0000
# Max Obs:                        149.00
#
#                                         Parameter Estimates
# ====================================================================================================
#                                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------------------
# Size of Government                   0.0047     0.0053     0.8905     0.3733     -0.0057      0.0152
# Legal System & Property Rights       0.0142     0.0046     3.0588     0.0023      0.0051      0.0233
# Sound Money                          0.0059     0.0028     2.0990     0.0360      0.0004      0.0115
# Freedom to trade internationally     0.0054     0.0043     1.2480     0.2122     -0.0031      0.0139
# Regulation                           0.0039     0.0030     1.3022     0.1930     -0.0020      0.0098
# ====================================================================================================
#
# F-test for Poolability: 4.5629
# P-value: 0.0000
# Distribution: F(148,1728)
#
# Included effects: Entity
# Diff Data
# Entity = False
# Time = True
# Diff Data
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     Log RGDP Per Capita   R-squared:                        0.0231
# Estimator:                    PanelOLS   R-squared (Between):              0.0356
# No. Observations:                 1882   R-squared (Within):               0.0184
# Date:                 Wed, Dec 01 2021   R-squared (Overall):              0.0329
# Time:                         07:43:44   Log-likelihood                    3339.5
# Cov. Estimator:              Clustered
#                                          F-statistic:                      8.8245
# Entities:                          162   P-value                           0.0000
# Avg Obs:                        11.617   Distribution:                  F(5,1863)
# Min Obs:                        0.0000
# Max Obs:                        14.000   F-statistic (robust):             5.2181
#                                          P-value                           0.0001
# Time periods:                       21   Distribution:                  F(5,1863)
# Avg Obs:                        89.619
# Min Obs:                        0.0000
# Max Obs:                        149.00
#
#                                         Parameter Estimates
# ====================================================================================================
#                                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------------------
# Size of Government                   0.0001     0.0052     0.0199     0.9841     -0.0101      0.0103
# Legal System & Property Rights       0.0101     0.0053     1.9114     0.0561     -0.0003      0.0206
# Sound Money                          0.0089     0.0031     2.8441     0.0045      0.0028      0.0151
# Freedom to trade internationally     0.0087     0.0047     1.8293     0.0675     -0.0006      0.0179
# Regulation                           0.0064     0.0033     1.9407     0.0524   -6.82e-05      0.0129
# ====================================================================================================
#
# F-test for Poolability: 19.247
# P-value: 0.0000
# Distribution: F(13,1863)
#
# Included effects: Time
# C:\Users\faria\anaconda3\lib\site-packages\linearmodels\panel\results.py:544: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   out_df: DataFrame = concat(out, 1)
# Diff Data
# Entity = False
# Time = False
# Diff Data
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     Log RGDP Per Capita   R-squared:                        0.0423
# Estimator:                    PanelOLS   R-squared (Between):              0.0631
# No. Observations:                 1882   R-squared (Within):               0.0076
# Date:                 Wed, Dec 01 2021   R-squared (Overall):              0.0423
# Time:                         07:43:44   Log-likelihood                    3013.0
# Cov. Estimator:              Clustered
#                                          F-statistic:                      16.594
# Entities:                          162   P-value                           0.0000
# Avg Obs:                        11.617   Distribution:                  F(5,1877)
# Min Obs:                        0.0000
# Max Obs:                        14.000   F-statistic (robust):             12.475
#                                          P-value                           0.0000
# Time periods:                       21   Distribution:                  F(5,1877)
# Avg Obs:                        89.619
# Min Obs:                        0.0000
# Max Obs:                        149.00
#
#                                         Parameter Estimates
# ====================================================================================================
#                                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------------------
# Size of Government                   0.0060     0.0055     1.0916     0.2752     -0.0048      0.0168
# Legal System & Property Rights       0.0188     0.0055     3.3997     0.0007      0.0080      0.0297
# Sound Money                          0.0112     0.0029     3.9050     0.0001      0.0056      0.0168
# Freedom to trade internationally     0.0064     0.0046     1.3736     0.1697     -0.0027      0.0155
# Regulation                           0.0163     0.0038     4.2619     0.0000      0.0088      0.0238
# ====================================================================================================

# %% [markdown]
# By adding the lag of logRGDP improved the model for the non-differenced data for all the effects.

# %%
import matplotlib.pyplot as plt
from linearmodels import PanelOLS
# . . . .
y_name = ["Log RGDP Per Capita"]
X_names = ["Log RGDP Per Capita Lag",
          "Size of Government", 
          "Legal System & Property Rights", 
          "Sound Money",
          "Freedom to trade internationally",
          "Regulation"]
for key, data in data_dict.items():
    for entity in [True, False]:
        for time in [True, False]:
            print(key)
            print("Entity =", entity)
            print("Time =", time)
            reg_data = data_dict[key].dropna()
            Y = reg_data[y_name]
            X = reg_data[X_names]
            X["Constant"] = 1
            # call panel_regression method        
            model = PanelOLS(Y,X, entity_effects=entity, time_effects=time)
            results = model.fit(cov_type='clustered', cluster_entity=True)
            print(key, results, sep ="\n") 
            reg_data["Predictor"] = results.predict()
            reg_data["Residuals"] = reg_data[y_name[0]].sub(reg_data["Predictor"])

            # plot distribution of residuals
            fig, ax = plt.subplots(figsize = (12,8))
            reg_data[["Residuals"]].plot.hist(bins = 100, ax = ax)
            plt.title(key + "\nEntity = " + str(entity) + " Time = " + str(time) )

            # plot observed vs. predicted values
            fig, ax = plt.subplots(figsize = (14,10))
            reg_data.plot.scatter(x = y_name[0],
                             y = "Predictor", 
                              s = 30, ax = ax)
            plt.xticks(rotation=90)
            plt.title(key + "\nEntity = " + str(entity) + " Time = " + str(time) )
            plt.show()
            plt.close()

            # plot observed against residuals
            fig, ax = plt.subplots(figsize = (14,10))
            reg_data.plot.scatter(x = y_name[0],
                             y = "Residuals", 
                              s = 30, ax = ax)
            ax.axhline(0, ls = "--", color = "k")
            plt.xticks(rotation=90)
            plt.title(key + "\nEntity = " + str(entity) + " Time = " + str(time) )
            plt.show()
            plt.close()
# Out:
# Data
# Entity = True
# Time = True
# Data
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     Log RGDP Per Capita   R-squared:                        0.8784
# Estimator:                    PanelOLS   R-squared (Between):              0.9982
# No. Observations:                 2031   R-squared (Within):               0.9228
# Date:                 Wed, Dec 01 2021   R-squared (Overall):              0.9974
# Time:                         07:44:51   Log-likelihood                    3973.5
# Cov. Estimator:              Clustered
#                                          F-statistic:                      2242.0
# Entities:                          162   P-value                           0.0000
# Avg Obs:                        12.537   Distribution:                  F(6,1862)
# Min Obs:                        0.0000
# Max Obs:                        15.000   F-statistic (robust):             482.18
#                                          P-value                           0.0000
# Time periods:                       22   Distribution:                  F(6,1862)
# Avg Obs:                        92.318
# Min Obs:                        0.0000
# Max Obs:                        149.00
#
#                                         Parameter Estimates
# ====================================================================================================
#                                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------------------
# Log RGDP Per Capita Lag              0.9752     0.0230     42.446     0.0000      0.9301      1.0202
# Size of Government                   0.0044     0.0035     1.2391     0.2155     -0.0025      0.0113
# Legal System & Property Rights      -0.0050     0.0041    -1.2043     0.2286     -0.0131      0.0031
# Sound Money                          0.0039     0.0026     1.5370     0.1245     -0.0011      0.0090
# Freedom to trade internationally    -0.0042     0.0053    -0.8038     0.4216     -0.0146      0.0061
# Regulation                          -0.0073     0.0043    -1.6749     0.0941     -0.0158      0.0012
# Constant                             0.2523     0.1923     1.3121     0.1897     -0.1249      0.6295
# ====================================================================================================
#
# F-test for Poolability: 7.0764
# P-value: 0.0000
# Distribution: F(162,1862)
#
# Included effects: Entity, Time
# C:\Users\faria\AppData\Local\Temp/ipykernel_16284/3312686217.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Constant"] = 1
# C:\Users\faria\anaconda3\lib\site-packages\linearmodels\panel\results.py:544: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   out_df: DataFrame = concat(out, 1)
# C:\Users\faria\AppData\Local\Temp/ipykernel_16284/3312686217.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reg_data["Predictor"] = results.predict()
# C:\Users\faria\AppData\Local\Temp/ipykernel_16284/3312686217.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reg_data["Residuals"] = reg_data[y_name[0]].sub(reg_data["Predictor"])
# Data
# Entity = True
# Time = False
# Data
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     Log RGDP Per Capita   R-squared:                        0.9247
# Estimator:                    PanelOLS   R-squared (Between):              0.9994
# No. Observations:                 2031   R-squared (Within):               0.9247
# Date:                 Wed, Dec 01 2021   R-squared (Overall):              0.9987
# Time:                         07:44:51   Log-likelihood                    3783.6
# Cov. Estimator:              Clustered
#                                          F-statistic:                      3839.7
# Entities:                          162   P-value                           0.0000
# Avg Obs:                        12.537   Distribution:                  F(6,1876)
# Min Obs:                        0.0000
# Max Obs:                        15.000   F-statistic (robust):             1285.9
#                                          P-value                           0.0000
# Time periods:                       22   Distribution:                  F(6,1876)
# Avg Obs:                        92.318
# Min Obs:                        0.0000
# Max Obs:                        149.00
#
#                                         Parameter Estimates
# ====================================================================================================
#                                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------------------
# Log RGDP Per Capita Lag              1.0164     0.0139     73.140     0.0000      0.9892      1.0437
# Size of Government                   0.0035     0.0033     1.0549     0.2916     -0.0030      0.0100
# Legal System & Property Rights      -0.0029     0.0040    -0.7229     0.4698     -0.0107      0.0050
# Sound Money                          0.0040     0.0024     1.6461     0.0999     -0.0008      0.0088
# Freedom to trade internationally    -0.0056     0.0041    -1.3674     0.1717     -0.0137      0.0025
# Regulation                          -0.0052     0.0037    -1.4165     0.1568     -0.0125      0.0020
# Constant                            -0.1368     0.1211    -1.1299     0.2587     -0.3742      0.1006
# ====================================================================================================
#
# F-test for Poolability: 4.3097
# P-value: 0.0000
# Distribution: F(148,1876)
#
# Included effects: Entity
# C:\Users\faria\AppData\Local\Temp/ipykernel_16284/3312686217.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Constant"] = 1
# Data
# Entity = False
# Time = True
# Data
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     Log RGDP Per Capita   R-squared:                        0.9989
# Estimator:                    PanelOLS   R-squared (Between):              0.9995
# No. Observations:                 2031   R-squared (Within):               0.9241
# Date:                 Wed, Dec 01 2021   R-squared (Overall):              0.9988
# Time:                         07:44:52   Log-likelihood                    3617.6
# Cov. Estimator:              Clustered
#                                          F-statistic:                   3.059e+05
# Entities:                          162   P-value                           0.0000
# Avg Obs:                        12.537   Distribution:                  F(6,2010)
# Min Obs:                        0.0000
# Max Obs:                        15.000   F-statistic (robust):          8.897e+04
#                                          P-value                           0.0000
# Time periods:                       22   Distribution:                  F(6,2010)
# Avg Obs:                        92.318
# Min Obs:                        0.0000
# Max Obs:                        149.00
#
#                                         Parameter Estimates
# ====================================================================================================
#                                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------------------
# Log RGDP Per Capita Lag              1.0050     0.0023     434.51     0.0000      1.0005      1.0096
# Size of Government                  -0.0027     0.0017    -1.6496     0.0992     -0.0060      0.0005
# Legal System & Property Rights      -0.0028     0.0019    -1.4829     0.1383     -0.0065      0.0009
# Sound Money                          0.0026     0.0019     1.4070     0.1596     -0.0010      0.0063
# Freedom to trade internationally    -0.0024     0.0028    -0.8418     0.4000     -0.0079      0.0032
# Regulation                          -0.0009     0.0023    -0.3864     0.6992     -0.0054      0.0036
# Constant                            -0.0338     0.0270    -1.2506     0.2112     -0.0869      0.0192
# ====================================================================================================
#
# F-test for Poolability: 19.812
# P-value: 0.0000
# Distribution: F(14,2010)
#
# Included effects: Time
# C:\Users\faria\anaconda3\lib\site-packages\linearmodels\panel\results.py:544: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   out_df: DataFrame = concat(out, 1)
# C:\Users\faria\AppData\Local\Temp/ipykernel_16284/3312686217.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reg_data["Predictor"] = results.predict()
# C:\Users\faria\AppData\Local\Temp/ipykernel_16284/3312686217.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reg_data["Residuals"] = reg_data[y_name[0]].sub(reg_data["Predictor"])
# Data
# Entity = False
# Time = False
# Data
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     Log RGDP Per Capita   R-squared:                        0.9988
# Estimator:                    PanelOLS   R-squared (Between):              0.9995
# No. Observations:                 2031   R-squared (Within):               0.9241
# Date:                 Wed, Dec 01 2021   R-squared (Overall):              0.9988
# Time:                         07:44:52   Log-likelihood                    3486.4
# Cov. Estimator:              Clustered
#                                          F-statistic:                   2.714e+05
# Entities:                          162   P-value                           0.0000
# Avg Obs:                        12.537   Distribution:                  F(6,2024)
# Min Obs:                        0.0000
# Max Obs:                        15.000   F-statistic (robust):          8.812e+04
#                                          P-value                           0.0000
# Time periods:                       22   Distribution:                  F(6,2024)
# Avg Obs:                        92.318
# Min Obs:                        0.0000
# Max Obs:                        149.00
#
#                                         Parameter Estimates
# ====================================================================================================
#                                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------------------
# Log RGDP Per Capita Lag              1.0052     0.0023     444.30     0.0000      1.0008      1.0097
# Size of Government                  -0.0029     0.0016    -1.7567     0.0791     -0.0061      0.0003
# Legal System & Property Rights      -0.0030     0.0018    -1.6641     0.0962     -0.0066      0.0005
# Sound Money                          0.0030     0.0019     1.6000     0.1098     -0.0007      0.0066
# Freedom to trade internationally    -0.0030     0.0027    -1.1396     0.2546     -0.0083      0.0022
# Regulation                       -3.685e-05     0.0022    -0.0170     0.9864     -0.0043      0.0042
# Constant                            -0.0372     0.0266    -1.4002     0.1616     -0.0894      0.0149
# ====================================================================================================
# C:\Users\faria\AppData\Local\Temp/ipykernel_16284/3312686217.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Constant"] = 1
# Diff Data
# Entity = True
# Time = True
# Diff Data
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     Log RGDP Per Capita   R-squared:                        0.0818
# Estimator:                    PanelOLS   R-squared (Between):              0.3265
# No. Observations:                 1882   R-squared (Within):               0.0754
# Date:                 Wed, Dec 01 2021   R-squared (Overall):              0.1668
# Time:                         07:44:53   Log-likelihood                    3763.3
# Cov. Estimator:              Clustered
#                                          F-statistic:                      25.464
# Entities:                          162   P-value                           0.0000
# Avg Obs:                        11.617   Distribution:                  F(6,1714)
# Min Obs:                        0.0000
# Max Obs:                        14.000   F-statistic (robust):             8.8186
#                                          P-value                           0.0000
# Time periods:                       21   Distribution:                  F(6,1714)
# Avg Obs:                        89.619
# Min Obs:                        0.0000
# Max Obs:                        149.00
#
#                                         Parameter Estimates
# ====================================================================================================
#                                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------------------
# Log RGDP Per Capita Lag              0.2549     0.0595     4.2853     0.0000      0.1382      0.3716
# Size of Government                  -0.0011     0.0051    -0.2236     0.8231     -0.0112      0.0089
# Legal System & Property Rights       0.0074     0.0058     1.2735     0.2030     -0.0040      0.0188
# Sound Money                          0.0080     0.0028     2.8807     0.0040      0.0025      0.0134
# Freedom to trade internationally     0.0020     0.0045     0.4331     0.6650     -0.0069      0.0108
# Regulation                           0.0022     0.0033     0.6514     0.5149     -0.0044      0.0087
# Constant                            -0.0168     0.0013    -12.809     0.0000     -0.0193     -0.0142
# ====================================================================================================
#
# F-test for Poolability: 4.8603
# P-value: 0.0000
# Distribution: F(161,1714)
#
# Included effects: Entity, Time
# C:\Users\faria\anaconda3\lib\site-packages\linearmodels\panel\results.py:544: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   out_df: DataFrame = concat(out, 1)
# Diff Data
# Entity = True
# Time = False
# Diff Data
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     Log RGDP Per Capita   R-squared:                        0.0799
# Estimator:                    PanelOLS   R-squared (Between):              0.3206
# No. Observations:                 1882   R-squared (Within):               0.0799
# Date:                 Wed, Dec 01 2021   R-squared (Overall):              0.1665
# Time:                         07:44:54   Log-likelihood                    3587.6
# Cov. Estimator:              Clustered
#                                          F-statistic:                      24.985
# Entities:                          162   P-value                           0.0000
# Avg Obs:                        11.617   Distribution:                  F(6,1727)
# Min Obs:                        0.0000
# Max Obs:                        14.000   F-statistic (robust):             8.4654
#                                          P-value                           0.0000
# Time periods:                       21   Distribution:                  F(6,1727)
# Avg Obs:                        89.619
# Min Obs:                        0.0000
# Max Obs:                        149.00
#
#                                         Parameter Estimates
# ====================================================================================================
#                                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------------------
# Log RGDP Per Capita Lag              0.2434     0.0507     4.7989     0.0000      0.1439      0.3429
# Size of Government                   0.0041     0.0051     0.8047     0.4211     -0.0059      0.0140
# Legal System & Property Rights       0.0113     0.0050     2.2494     0.0246      0.0014      0.0211
# Sound Money                          0.0051     0.0028     1.8345     0.0668     -0.0003      0.0105
# Freedom to trade internationally     0.0025     0.0043     0.5750     0.5654     -0.0060      0.0110
# Regulation                           0.0021     0.0031     0.6783     0.4977     -0.0039      0.0081
# Constant                            -0.0170     0.0011    -15.508     0.0000     -0.0192     -0.0149
# ====================================================================================================
#
# F-test for Poolability: 2.4322
# P-value: 0.0000
# Distribution: F(148,1727)
#
# Included effects: Entity
# C:\Users\faria\AppData\Local\Temp/ipykernel_16284/3312686217.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Constant"] = 1
# Diff Data
# Entity = False
# Time = True
# Diff Data
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     Log RGDP Per Capita   R-squared:                        0.2314
# Estimator:                    PanelOLS   R-squared (Between):              0.5560
# No. Observations:                 1882   R-squared (Within):               0.0215
# Date:                 Wed, Dec 01 2021   R-squared (Overall):              0.1998
# Time:                         07:44:54   Log-likelihood                    3565.2
# Cov. Estimator:              Clustered
#                                          F-statistic:                      93.446
# Entities:                          162   P-value                           0.0000
# Avg Obs:                        11.617   Distribution:                  F(6,1862)
# Min Obs:                        0.0000
# Max Obs:                        14.000   F-statistic (robust):             25.476
#                                          P-value                           0.0000
# Time periods:                       21   Distribution:                  F(6,1862)
# Avg Obs:                        89.619
# Min Obs:                        0.0000
# Max Obs:                        149.00
#
#                                         Parameter Estimates
# ====================================================================================================
#                                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------------------
# Log RGDP Per Capita Lag              0.4815     0.0556     8.6553     0.0000      0.3724      0.5906
# Size of Government                  -0.0002     0.0048    -0.0494     0.9606     -0.0097      0.0093
# Legal System & Property Rights       0.0062     0.0060     1.0331     0.3017     -0.0055      0.0179
# Sound Money                          0.0081     0.0030     2.6532     0.0080      0.0021      0.0140
# Freedom to trade internationally     0.0016     0.0048     0.3269     0.7438     -0.0079      0.0110
# Regulation                           0.0036     0.0034     1.0512     0.2933     -0.0031      0.0102
# Constant                            -0.0118     0.0016    -7.4365     0.0000     -0.0149     -0.0087
# ====================================================================================================
#
# F-test for Poolability: 25.787
# P-value: 0.0000
# Distribution: F(13,1862)
#
# Included effects: Time
# C:\Users\faria\anaconda3\lib\site-packages\linearmodels\panel\results.py:544: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   out_df: DataFrame = concat(out, 1)
# Diff Data
# Entity = False
# Time = False
# Diff Data
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     Log RGDP Per Capita   R-squared:                        0.2037
# Estimator:                    PanelOLS   R-squared (Between):              0.5294
# No. Observations:                 1882   R-squared (Within):               0.0404
# Date:                 Wed, Dec 01 2021   R-squared (Overall):              0.2037
# Time:                         07:44:55   Log-likelihood                    3409.4
# Cov. Estimator:              Clustered
#                                          F-statistic:                      79.930
# Entities:                          162   P-value                           0.0000
# Avg Obs:                        11.617   Distribution:                  F(6,1875)
# Min Obs:                        0.0000
# Max Obs:                        14.000   F-statistic (robust):             22.271
#                                          P-value                           0.0000
# Time periods:                       21   Distribution:                  F(6,1875)
# Avg Obs:                        89.619
# Min Obs:                        0.0000
# Max Obs:                        149.00
#
#                                         Parameter Estimates
# ====================================================================================================
#                                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------------------
# Log RGDP Per Capita Lag              0.4445     0.0502     8.8500     0.0000      0.3460      0.5430
# Size of Government                   0.0041     0.0049     0.8374     0.4025     -0.0055      0.0137
# Legal System & Property Rights       0.0089     0.0054     1.6417     0.1008     -0.0017      0.0196
# Sound Money                          0.0048     0.0030     1.6079     0.1080     -0.0010      0.0106
# Freedom to trade internationally     0.0027     0.0047     0.5860     0.5579     -0.0064      0.0119
# Regulation                           0.0027     0.0033     0.8173     0.4138     -0.0038      0.0092
# Constant                            -0.0127     0.0015    -8.2216     0.0000     -0.0157     -0.0097
# ====================================================================================================
# C:\Users\faria\AppData\Local\Temp/ipykernel_16284/3312686217.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Constant"] = 1
