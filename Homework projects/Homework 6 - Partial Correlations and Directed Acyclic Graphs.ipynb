# %% [markdown]
# ## Homework 6: Partial Correlations and Directed Acyclic Graphs

# %% [markdown]
# ## 1. Create a graphical skeleton like the one created above using the Economic Freedom of the World Index and Real GDP.

# %%
import random
import numpy as np
import pandas as pd

# %%
# !pip install pingouin
# Out:
# Collecting pingouin
#   Using cached pingouin-0.5.0.tar.gz (182 kB)
# Requirement already satisfied: numpy>=1.19 in c:\users\faria\anaconda3\lib\site-packages (from pingouin) (1.20.3)
# Requirement already satisfied: scipy>=1.7 in c:\users\faria\anaconda3\lib\site-packages (from pingouin) (1.7.1)
# Requirement already satisfied: pandas>=1.0 in c:\users\faria\anaconda3\lib\site-packages (from pingouin) (1.3.4)
# Requirement already satisfied: matplotlib>=3.0.2 in c:\users\faria\anaconda3\lib\site-packages (from pingouin) (3.4.3)
# Requirement already satisfied: seaborn>=0.9.0 in c:\users\faria\anaconda3\lib\site-packages (from pingouin) (0.11.2)
# Requirement already satisfied: statsmodels>=0.12.0 in c:\users\faria\anaconda3\lib\site-packages (from pingouin) (0.12.2)
# Requirement already satisfied: scikit-learn in c:\users\faria\anaconda3\lib\site-packages (from pingouin) (0.24.2)
# Collecting pandas_flavor>=0.2.0
#   Using cached pandas_flavor-0.2.0-py2.py3-none-any.whl (6.6 kB)
# Collecting outdated
#   Using cached outdated-0.2.1-py3-none-any.whl (7.5 kB)
# Collecting tabulate
#   Using cached tabulate-0.8.9-py3-none-any.whl (25 kB)
# Requirement already satisfied: cycler>=0.10 in c:\users\faria\anaconda3\lib\site-packages (from matplotlib>=3.0.2->pingouin) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\faria\anaconda3\lib\site-packages (from matplotlib>=3.0.2->pingouin) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\faria\anaconda3\lib\site-packages (from matplotlib>=3.0.2->pingouin) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\faria\anaconda3\lib\site-packages (from matplotlib>=3.0.2->pingouin) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\faria\anaconda3\lib\site-packages (from matplotlib>=3.0.2->pingouin) (2.8.2)
# Requirement already satisfied: six in c:\users\faria\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=3.0.2->pingouin) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\faria\anaconda3\lib\site-packages (from pandas>=1.0->pingouin) (2021.3)
# Collecting xarray
#   Downloading xarray-0.20.1-py3-none-any.whl (835 kB)
# Requirement already satisfied: patsy>=0.5 in c:\users\faria\anaconda3\lib\site-packages (from statsmodels>=0.12.0->pingouin) (0.5.2)
# Requirement already satisfied: requests in c:\users\faria\anaconda3\lib\site-packages (from outdated->pingouin) (2.26.0)
# Collecting littleutils
#   Using cached littleutils-0.2.2.tar.gz (6.6 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\faria\anaconda3\lib\site-packages (from requests->outdated->pingouin) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\faria\anaconda3\lib\site-packages (from requests->outdated->pingouin) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\faria\anaconda3\lib\site-packages (from requests->outdated->pingouin) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\faria\anaconda3\lib\site-packages (from requests->outdated->pingouin) (2.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\faria\anaconda3\lib\site-packages (from scikit-learn->pingouin) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\faria\anaconda3\lib\site-packages (from scikit-learn->pingouin) (1.1.0)
# Building wheels for collected packages: pingouin, littleutils
#   Building wheel for pingouin (setup.py): started
#   Building wheel for pingouin (setup.py): finished with status 'done'
#   Created wheel for pingouin: filename=pingouin-0.5.0-py3-none-any.whl size=193661 sha256=42041e84c114ddf6dc5734e25e6d8b5faaac009245946aee42b5b38b16e5e092
#   Stored in directory: c:\users\faria\appdata\local\pip\cache\wheels\ac\42\e9\bd0edc18701d9b7ab4b09be127909823f131054f35373abc0c
#   Building wheel for littleutils (setup.py): started
#   Building wheel for littleutils (setup.py): finished with status 'done'
#   Created wheel for littleutils: filename=littleutils-0.2.2-py3-none-any.whl size=7048 sha256=55af92e72ad7203b09da4c0193b20166e5e8bc5abfbd7a801904f50ec2b1fd51
#   Stored in directory: c:\users\faria\appdata\local\pip\cache\wheels\04\bb\0d\2d02ec45f29c48d6192476bfb59c5a0e64b605e7212374dd15
# Successfully built pingouin littleutils
# Installing collected packages: xarray, littleutils, tabulate, pandas-flavor, outdated, pingouin
# Successfully installed littleutils-0.2.2 outdated-0.2.1 pandas-flavor-0.2.0 pingouin-0.5.0 tabulate-0.8.9 xarray-0.20.1

# %%
import pingouin

# %%
data = pd.read_csv("fraserDataWithRGDPPC.csv", 
                   index_col=[0,1],
                  parse_dates = True).dropna()
years = np.array(sorted(list(set(data.index.get_level_values("Year")))))
years = pd.date_range(years[0], years[-2], freq = "AS")
countries = sorted(list(set(data.index.get_level_values("ISO_Code"))))
index_names = list(data.index.names)
multi_index = pd.MultiIndex.from_product([countries, 
                                          years[:-1]], 
                                         names =data.index.names)
data = data.reindex(multi_index)
data
# Out:
#                           EFW  Size of Government  \
# ISO_Code Year
# AGO      1970-01-01       NaN                 NaN
#          1971-01-01       NaN                 NaN
#          1972-01-01       NaN                 NaN
#          1973-01-01       NaN                 NaN
#          1974-01-01       NaN                 NaN
# ...                       ...                 ...
# ZWE      2010-01-01  4.374917            6.514112
#          2011-01-01  4.843441            6.424630
#          2012-01-01  4.971192            6.670469
#          2013-01-01  5.246723            6.325105
#          2014-01-01  5.582478            6.433165
#
#                      Legal System & Property Rights  Sound Money  \
# ISO_Code Year
# AGO      1970-01-01                             NaN          NaN
#          1971-01-01                             NaN          NaN
#          1972-01-01                             NaN          NaN
#          1973-01-01                             NaN          NaN
#          1974-01-01                             NaN          NaN
# ...                                             ...          ...
# ZWE      2010-01-01                        3.826300     1.972000
#          2011-01-01                        3.943725     4.109198
#          2012-01-01                        4.013004     5.378742
#          2013-01-01                        3.575827     6.895530
#          2014-01-01                        3.615584     7.966798
#
#                      Freedom to trade internationally  Regulation  \
# ISO_Code Year
# AGO      1970-01-01                               NaN         NaN
#          1971-01-01                               NaN         NaN
#          1972-01-01                               NaN         NaN
#          1973-01-01                               NaN         NaN
#          1974-01-01                               NaN         NaN
# ...                                               ...         ...
# ZWE      2010-01-01                          4.907822    4.654352
#          2011-01-01                          5.366773    4.372878
#          2012-01-01                          5.132305    3.661438
#          2013-01-01                          5.589087    3.848068
#          2014-01-01                          5.909121    3.987721
#
#                      RGDP Per Capita
# ISO_Code Year
# AGO      1970-01-01              NaN
#          1971-01-01              NaN
#          1972-01-01              NaN
#          1973-01-01              NaN
#          1974-01-01              NaN
# ...                              ...
# ZWE      2010-01-01           1404.0
#          2011-01-01           1515.0
#          2012-01-01           1604.0
#          2013-01-01           1604.0
#          2014-01-01           1594.0
#
# [6840 rows x 7 columns]

# %%
keys = list(data.keys())[1:]
df = data.copy()
df["RGDP Per Capita"] = data["RGDP Per Capita"].groupby("ISO_Code").pct_change()
df =df[keys].diff()
df = df.rename(columns={key:key.replace(",", "\n") for key in df}).dropna()
df
# Out:
#                      Size of Government  Legal System & Property Rights  \
# ISO_Code Year
# AGO      2007-01-01           -0.103686                        0.022720
#          2008-01-01            0.068152                        0.084915
#          2009-01-01            1.797574                       -0.031306
#          2010-01-01           -1.366275                        0.050092
#          2011-01-01            0.096683                       -0.087293
# ...                                 ...                             ...
# ZWE      2010-01-01           -0.855503                        0.117071
#          2011-01-01           -0.089482                        0.117425
#          2012-01-01            0.245839                        0.069279
#          2013-01-01           -0.345364                       -0.437177
#          2014-01-01            0.108060                        0.039756
#
#                      Sound Money  Freedom to trade internationally  \
# ISO_Code Year
# AGO      2007-01-01     0.392129                         -0.043488
#          2008-01-01     0.579510                         -0.427486
#          2009-01-01     0.205423                          0.123869
#          2010-01-01     0.331967                          0.377986
#          2011-01-01     0.101526                          0.020767
# ...                          ...                               ...
# ZWE      2010-01-01     1.024500                          0.041328
#          2011-01-01     2.137198                          0.458951
#          2012-01-01     1.269544                         -0.234468
#          2013-01-01     1.516788                          0.456781
#          2014-01-01     1.071268                          0.320035
#
#                      Regulation  RGDP Per Capita
# ISO_Code Year
# AGO      2007-01-01    0.218491         0.017840
#          2008-01-01   -0.302899        -0.084366
#          2009-01-01   -0.210128        -0.110907
#          2010-01-01    0.680722         0.009600
#          2011-01-01   -0.701467         0.004508
# ...                         ...              ...
# ZWE      2010-01-01   -0.024469         0.017729
#          2011-01-01   -0.281474        -0.010157
#          2012-01-01   -0.711440        -0.020314
#          2013-01-01    0.186630        -0.058746
#          2014-01-01    0.139653        -0.006234
#
# [1808 rows x 6 columns]

# %%
df.corr()
# Out:
#                                   Size of Government  \
# Size of Government                          1.000000
# Legal System & Property Rights              0.056615
# Sound Money                                -0.013536
# Freedom to trade internationally            0.031969
# Regulation                                  0.052546
# RGDP Per Capita                             0.013708
#
#                                   Legal System & Property Rights  Sound Money  \
# Size of Government                                      0.056615    -0.013536
# Legal System & Property Rights                          1.000000     0.021813
# Sound Money                                             0.021813     1.000000
# Freedom to trade internationally                        0.104924     0.130231
# Regulation                                              0.207265     0.033420
# RGDP Per Capita                                         0.068795    -0.031347
#
#                                   Freedom to trade internationally  \
# Size of Government                                        0.031969
# Legal System & Property Rights                            0.104924
# Sound Money                                               0.130231
# Freedom to trade internationally                          1.000000
# Regulation                                                0.070488
# RGDP Per Capita                                           0.040761
#
#                                   Regulation  RGDP Per Capita
# Size of Government                  0.052546         0.013708
# Legal System & Property Rights      0.207265         0.068795
# Sound Money                         0.033420        -0.031347
# Freedom to trade internationally    0.070488         0.040761
# Regulation                          1.000000         0.124689
# RGDP Per Capita                     0.124689         1.000000

# %%
import statsmodels.api as sm

residuals = {}
for y_var in df.keys():
    X_vars = list(df.keys())
    X_vars.remove(y_var)
    X = df[X_vars]
    X["Constant"] = 1
    y = df[[y_var]]
    model = sm.OLS(y, X)
    results = model.fit()
    residuals[y_var] = results.resid
residuals = pd.DataFrame(residuals)

# %%
residuals
# Out:
#                      Size of Government  Legal System & Property Rights  \
# ISO_Code Year
# AGO      2007-01-01           -0.114134                       -0.014037
#          2008-01-01            0.097522                        0.188195
#          2009-01-01            1.806662                       -0.041575
#          2010-01-01           -1.415532                       -0.061361
#          2011-01-01            0.132866                        0.037261
# ...                                 ...                             ...
# ZWE      2010-01-01           -0.852219                        0.141471
#          2011-01-01           -0.068811                        0.131042
#          2012-01-01            0.299726                        0.211703
#          2013-01-01           -0.324418                       -0.489596
#          2014-01-01            0.100074                       -0.016722
#
#                      Sound Money  Freedom to trade internationally  \
# ISO_Code Year
# AGO      2007-01-01     0.342342                         -0.086190
#          2008-01-01     0.599599                         -0.456258
#          2009-01-01     0.149415                          0.100800
#          2010-01-01     0.146716                          0.346911
#          2011-01-01     0.082395                          0.051776
# ...                          ...                               ...
# ZWE      2010-01-01     0.950131                         -0.037762
#          2011-01-01     2.003512                          0.283006
#          2012-01-01     1.294684                         -0.317963
#          2013-01-01     1.346889                          0.381682
#          2014-01-01     0.952280                          0.220011
#
#                      Regulation  RGDP Per Capita
# ISO_Code Year
# AGO      2007-01-01    0.165175         0.021755
#          2008-01-01   -0.307282        -0.065414
#          2009-01-01   -0.247416        -0.099753
#          2010-01-01    0.651456         0.000155
#          2011-01-01   -0.729087         0.028820
# ...                         ...              ...
# ZWE      2010-01-01   -0.087337         0.029747
#          2011-01-01   -0.390606         0.010584
#          2012-01-01   -0.773102         0.010629
#          2013-01-01    0.235388        -0.047080
#          2014-01-01    0.062467         0.000473
#
# [1808 rows x 6 columns]

# %%
residuals.corr()[residuals.corr().abs() < 1].mul(-1).fillna(1).round(2)
# Out:
#                                   Size of Government  \
# Size of Government                              1.00
# Legal System & Property Rights                  0.04
# Sound Money                                    -0.02
# Freedom to trade internationally                0.03
# Regulation                                      0.04
# RGDP Per Capita                                 0.00
#
#                                   Legal System & Property Rights  Sound Money  \
# Size of Government                                          0.04        -0.02
# Legal System & Property Rights                              1.00         0.01
# Sound Money                                                 0.01         1.00
# Freedom to trade internationally                            0.09         0.13
# Regulation                                                  0.19         0.03
# RGDP Per Capita                                             0.04        -0.04
#
#                                   Freedom to trade internationally  \
# Size of Government                                            0.03
# Legal System & Property Rights                                0.09
# Sound Money                                                   0.13
# Freedom to trade internationally                              1.00
# Regulation                                                    0.04
# RGDP Per Capita                                               0.03
#
#                                   Regulation  RGDP Per Capita
# Size of Government                      0.04             0.00
# Legal System & Property Rights          0.19             0.04
# Sound Money                             0.03            -0.04
# Freedom to trade internationally        0.04             0.03
# Regulation                              1.00             0.11
# RGDP Per Capita                         0.11             1.00

# %%
df.pcorr().round(2)
# Out:
#                                   Size of Government  \
# Size of Government                              1.00
# Legal System & Property Rights                  0.04
# Sound Money                                    -0.02
# Freedom to trade internationally                0.03
# Regulation                                      0.04
# RGDP Per Capita                                 0.00
#
#                                   Legal System & Property Rights  Sound Money  \
# Size of Government                                          0.04        -0.02
# Legal System & Property Rights                              1.00         0.01
# Sound Money                                                 0.01         1.00
# Freedom to trade internationally                            0.09         0.13
# Regulation                                                  0.19         0.03
# RGDP Per Capita                                             0.04        -0.04
#
#                                   Freedom to trade internationally  \
# Size of Government                                            0.03
# Legal System & Property Rights                                0.09
# Sound Money                                                   0.13
# Freedom to trade internationally                              1.00
# Regulation                                                    0.04
# RGDP Per Capita                                               0.03
#
#                                   Regulation  RGDP Per Capita
# Size of Government                      0.04             0.00
# Legal System & Property Rights          0.19             0.04
# Sound Money                             0.03            -0.04
# Freedom to trade internationally        0.04             0.03
# Regulation                              1.00             0.11
# RGDP Per Capita                         0.11             1.00

# %%
from datlib.plots import *
corr_matrix_heatmap(df.corr())

# %%
corr_matrix_heatmap(df.pcorr())

# %%
pcorr_pvalues = {}

for y, Y in residuals.items():
    pcorr_pvalues[y] = {}
    for x, X in residuals.items():
        if x != y:
            pcorr_pvalues[y][x] = sm.OLS(Y,X).fit().pvalues[x]
        else:
            pcorr_pvalues[y][x] = np.NaN
pd.DataFrame(pcorr_pvalues).round(2)
# Out:
#                                   Size of Government  \
# Size of Government                               NaN
# Legal System & Property Rights                  0.06
# Sound Money                                     0.42
# Freedom to trade internationally                0.26
# Regulation                                      0.09
# RGDP Per Capita                                 0.87
#
#                                   Legal System & Property Rights  Sound Money  \
# Size of Government                                          0.06         0.42
# Legal System & Property Rights                               NaN         0.80
# Sound Money                                                 0.80          NaN
# Freedom to trade internationally                            0.00         0.00
# Regulation                                                  0.00         0.23
# RGDP Per Capita                                             0.08         0.09
#
#                                   Freedom to trade internationally  \
# Size of Government                                            0.26
# Legal System & Property Rights                                0.00
# Sound Money                                                   0.00
# Freedom to trade internationally                               NaN
# Regulation                                                    0.08
# RGDP Per Capita                                               0.16
#
#                                   Regulation  RGDP Per Capita
# Size of Government                      0.09             0.87
# Legal System & Property Rights          0.00             0.08
# Sound Money                             0.23             0.09
# Freedom to trade internationally        0.08             0.16
# Regulation                               NaN             0.00
# RGDP Per Capita                         0.00              NaN

# %%
undirected_graph = {key:[] for key in df.keys()}
for x in undirected_graph:
    undirected_graph[x] = [y for y in df.keys() if y != x]
undirected_graph
# Out:
# {'Size of Government': ['Legal System & Property Rights',
#   'Sound Money',
#   'Freedom to trade internationally',
#   'Regulation',
#   'RGDP Per Capita'],
#  'Legal System & Property Rights': ['Size of Government',
#   'Sound Money',
#   'Freedom to trade internationally',
#   'Regulation',
#   'RGDP Per Capita'],
#  'Sound Money': ['Size of Government',
#   'Legal System & Property Rights',
#   'Freedom to trade internationally',
#   'Regulation',
#   'RGDP Per Capita'],
#  'Freedom to trade internationally': ['Size of Government',
#   'Legal System & Property Rights',
#   'Sound Money',
#   'Regulation',
#   'RGDP Per Capita'],
#  'Regulation': ['Size of Government',
#   'Legal System & Property Rights',
#   'Sound Money',
#   'Freedom to trade internationally',
#   'RGDP Per Capita'],
#  'RGDP Per Capita': ['Size of Government',
#   'Legal System & Property Rights',
#   'Sound Money',
#   'Freedom to trade internationally',
#   'Regulation']}

# %%
import copy
p_val = 0.01
def build_skeleton(df, undirected_graph):
    def check_remaining_controls(control_vars, undirected_graph, x, y, controls_used) :
        c_used = copy.copy(controls_used)
        for c_var in control_vars:
            if y not in undirected_graph[x]:
                break
            c_used.append(c_var)
            test = df.partial_corr(x = x, y = y, covar=c_used,
                                  method = "pearson")
            if test["p-val"].values[0] > p_val: 
                undirected_graph[x].remove(y)
                break
            else:
                remaining_controls = copy.copy(control_vars)
                remaining_controls.remove(c_var)
                check_remaining_controls(remaining_controls, undirected_graph, x, y, c_used)

    for x in df.keys():
        ys = undirected_graph[x]
        for y in df.keys():
            if x !=y:
                test = df.partial_corr(x=x,
                                      y=y,
                                      covar=None,
                                      method="pearson")
                if test["p-val"].values[0] > p_val:
                    undirected_graph[x].remove(y)
                else:
                    control_vars = [z for z in df.keys() if z !=y and z !=x]
                    check_remaining_controls(control_vars, undirected_graph, x, y, [])
    return undirected_graph

print(build_skeleton(df, undirected_graph))
# Out:
# {'Size of Government': [], 'Legal System & Property Rights': ['Freedom to trade internationally', 'Regulation'], 'Sound Money': ['Freedom to trade internationally'], 'Freedom to trade internationally': ['Legal System & Property Rights', 'Sound Money'], 'Regulation': ['Legal System & Property Rights', 'RGDP Per Capita'], 'RGDP Per Capita': ['Regulation']}

# %%
import matplotlib.pyplot as plt
import networkx as nx

# %%
def graph_DAG(undirected_graph, df, title = "DAG Structure"):
    pcorr_matrix = df.pcorr()
    graph = nx.Graph()
    edges = []
    edge_labels = {}
    for key in undirected_graph:
        for key2 in undirected_graph[key]:
            if (key2, key) not in edges:
                edge = (key.replace(" ","\n"), key2[0].replace(" ","\n"))
                edges.append(edge)
                edge_labels[edge] = str(round(pcorr_matrix.loc[key][key2],2))
    
    graph.add_edges_from(edges)
    color_map = ["C0" for g in graph]
    
    fix, ax = plt.subplots(figsize = (20,12))
    graph.nodes()
    plt.tight_layout()
    #pos = nx.spring_layouut(graph)
    pos = nx.spring_layout(graph)
    plt.title(title, fontsize = 30)
    nx.draw_networkx(graph, 
                     pos, 
                     node_color=color_map, 
                     node_size = 1000,
                     with_labels=True,  
                     arrows=False,
                     font_size = 20, 
                     alpha = 1,
                     font_color = "black",
                     ax = ax)
    nx.draw_networkx_edge_labels(graph,
                                 pos,
                                 edge_labels=edge_labels,
                                 font_color='green',
                                 font_size=20)
    
    
    plt.show()
    
graph_DAG(undirected_graph, df)

# %%
# !pip install pgmpy
# Out:
# Collecting pgmpy
#   Using cached pgmpy-0.1.16-py3-none-any.whl (1.9 MB)
# Requirement already satisfied: statsmodels in c:\users\faria\anaconda3\lib\site-packages (from pgmpy) (0.12.2)
# Requirement already satisfied: pandas in c:\users\faria\anaconda3\lib\site-packages (from pgmpy) (1.3.4)
# Requirement already satisfied: joblib in c:\users\faria\anaconda3\lib\site-packages (from pgmpy) (1.1.0)
# Requirement already satisfied: networkx in c:\users\faria\anaconda3\lib\site-packages (from pgmpy) (2.6.3)
# Collecting torch
#   Downloading torch-1.10.0-cp39-cp39-win_amd64.whl (226.5 MB)
# Requirement already satisfied: scipy in c:\users\faria\anaconda3\lib\site-packages (from pgmpy) (1.7.1)
# Requirement already satisfied: pyparsing in c:\users\faria\anaconda3\lib\site-packages (from pgmpy) (3.0.4)
# Requirement already satisfied: tqdm in c:\users\faria\anaconda3\lib\site-packages (from pgmpy) (4.62.3)
# Requirement already satisfied: scikit-learn in c:\users\faria\anaconda3\lib\site-packages (from pgmpy) (0.24.2)
# Requirement already satisfied: numpy in c:\users\faria\anaconda3\lib\site-packages (from pgmpy) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\faria\anaconda3\lib\site-packages (from pandas->pgmpy) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\faria\anaconda3\lib\site-packages (from pandas->pgmpy) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\faria\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->pgmpy) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\faria\anaconda3\lib\site-packages (from scikit-learn->pgmpy) (2.2.0)
# Requirement already satisfied: patsy>=0.5 in c:\users\faria\anaconda3\lib\site-packages (from statsmodels->pgmpy) (0.5.2)
# Requirement already satisfied: typing-extensions in c:\users\faria\anaconda3\lib\site-packages (from torch->pgmpy) (3.10.0.2)
# Requirement already satisfied: colorama in c:\users\faria\anaconda3\lib\site-packages (from tqdm->pgmpy) (0.4.4)
# Installing collected packages: torch, pgmpy
# Successfully installed pgmpy-0.1.16 torch-1.10.0

# %%
from pgmpy.estimators import PC

# %%
from pgmpy.estimators import PC
c = PC(df)
max_cond_vars = len(df.keys()) - 2
model = c.estimate(return_type = "dag",
                   variant= "parallel",    #"orig", "stable"
                   significance_level = p_val, 
                   max_cond_vars = max_cond_vars, 
                   ci_test = "pearsonr")
edges = model.edges()
edges
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# OutEdgeView([('Legal System & Property Rights', 'Freedom to trade internationally'), ('Sound Money', 'Freedom to trade internationally'), ('Regulation', 'Legal System & Property Rights'), ('RGDP Per Capita', 'Regulation')])

# %%
from matplotlib.patches import ArrowStyle
def graph_DAG(edges, df, title=""):
    graph = nx.DiGraph()
    
    edge_labels ={}
    for edge in edges:
        controls = [key for key in df.keys() if key not in edge]
        controls = list(set(controls))
        keep_controls = []
        for control in controls:
            control_edges = [ctrl_edge for ctrl_edge in edges if control]
            if (control, edge[1]) in control_edges:
                print("keep control:", control)
                keep_controls.append(control)
            print(edge, keep_controls)
            pcorr = df[[edge[0], edge[1]]+keep_controls].pcorr()
            edge_labels[edge] = str(round(pcorr[edge[0]].loc[edge[1]],2))
    graph.add_edges_from(edges)
    color_map =["C0" for g in graph]
    fig, ax = plt.subplots(figsize = (20,12))
    graph.nodes()
    plt.tight_layout()
    pos = nx.spring_layout(graph)
    plt.title(title, fontsize = 30)
    nx.draw_networkx(graph, 
                     pos, 
                     node_color=color_map, 
                     node_size = 1200,
                     font_color = "black",
                     font_size = 26, 
                     alpha = 1,
                     width = 1, 
                     edge_color = "C1",
                     arrowstyle=ArrowStyle("Fancy, head_length=3, head_width=1.5, tail_width=.1"), ax = ax)
    
    nx.draw_networkx_edge_labels(graph,
                                 pos,
                                 edge_labels = edge_labels,
                                 font_color = "green",
                                 font_size = 20)
    
    plt.show()
graph_DAG(edges, df, title = "Directed Acyclic Graph")
# Out:
# keep control: Sound Money
# ('Legal System & Property Rights', 'Freedom to trade internationally') ['Sound Money']
# ('Legal System & Property Rights', 'Freedom to trade internationally') ['Sound Money']
# ('Legal System & Property Rights', 'Freedom to trade internationally') ['Sound Money']
# ('Legal System & Property Rights', 'Freedom to trade internationally') ['Sound Money']
# keep control: Legal System & Property Rights
# ('Sound Money', 'Freedom to trade internationally') ['Legal System & Property Rights']
# ('Sound Money', 'Freedom to trade internationally') ['Legal System & Property Rights']
# ('Sound Money', 'Freedom to trade internationally') ['Legal System & Property Rights']
# ('Sound Money', 'Freedom to trade internationally') ['Legal System & Property Rights']
# ('Regulation', 'Legal System & Property Rights') []
# ('Regulation', 'Legal System & Property Rights') []
# ('Regulation', 'Legal System & Property Rights') []
# ('Regulation', 'Legal System & Property Rights') []
# ('RGDP Per Capita', 'Regulation') []
# ('RGDP Per Capita', 'Regulation') []
# ('RGDP Per Capita', 'Regulation') []
# ('RGDP Per Capita', 'Regulation') []
