# %% [markdown]
# # Econ 611 Computational Economics
# ### Submitted by Faria Tabassum
# ### Date: 3rd October 2021.

# %% [markdown]
# ## Project Proposal
# ### Topic: Relationship between Trade, GDP, and Population of Bangladesh (1960- 2020)

# %% [markdown]
# For this project, I want to see how the GDP and population of Bangladesh affect the volume of trade of that country. For trade, I will use the export of goods and services data. For the country, I will use the data of Bangladesh for 40 years to see the trend among the variables. I will also add population as a control variable.
#
# Later, I will add more countries to compare the results for different countries of different income levels. Thus, the problem this project intends to explore is the impact of GDP and population on a country’s level of export over the years.
#
# Variables Description:
#
# Exports of goods and services represent the value of all goods and other market services provided to the rest of the world. They include the value of merchandise, freight, insurance, transport, travel, royalties, license fees, and other services, such as communication, construction, financial, information, business, personal, and government services. They exclude compensation of employees and investment income (formerly called factor services) and transfer payments. Data are in constant 2010 U.S. dollars. This variable is quantitative.
#
# Motivation:
# My graduate thesis is related to International Trade and Technological Innovation. According to Grossman & Helpman (1990), Technological Innovation affects Economic Growth. On the other hand, International Trade also affects Economic growth ( (Hsu, Riezman, & Wang, 2019). This motivated me to see whether there is also a relationship between International Trade and Economic
# Growth.
#
# Data Source:
# I will use the country data from World Development Indicator by the World Bank. Link of the data source is the following: World Development Indicators | DataBank (worldbank.org)
#
#
#
# Method: To see the relationship, I will use a Multiple Linear Regression Model.
# I will use a scatter plot with a regression line to see the relationship between Trade and GDP.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
#Importing the data
df = pd.read_excel (r'C:\Users\faria\OneDrive - North Dakota University System\Desktop\MS\Fall 2021\611\Project\data.xlsx'
            )

# %%
print (df)
# Out:
#     year           gdp        export  population
# 0   1960  4.274894e+09  6.566516e+08    48013505
# 1   1961  4.817580e+09  5.811294e+08    49362834
# 2   1962  5.081413e+09  7.019842e+08    50752150
# 3   1963  5.319458e+09  7.358943e+08    52202008
# 4   1964  5.386055e+09  7.634360e+08    53741721
# ..   ...           ...           ...         ...
# 56  2016  2.214152e+11  2.822963e+10   157977151
# 57  2017  2.497109e+11  2.756832e+10   159685421
# 58  2018  2.740390e+11  2.979814e+10   161376713
# 59  2019  3.025634e+11  3.305742e+10   163046173
# 60  2020  3.242392e+11  2.769330e+10   164689383
#
# [61 rows x 4 columns]

# %%
df.head()
# Out:
#    year           gdp        export  population
# 0  1960  4.274894e+09  6.566516e+08    48013505
# 1  1961  4.817580e+09  5.811294e+08    49362834
# 2  1962  5.081413e+09  7.019842e+08    50752150
# 3  1963  5.319458e+09  7.358943e+08    52202008
# 4  1964  5.386055e+09  7.634360e+08    53741721

# %%
# create a figure and axis
fig, ax = plt.subplots()

# scatter the gdp and year
ax.scatter(df['year'], df['gdp'])

# set a title and labels
ax.set_title('GDP over the Years')
ax.set_xlabel('year')
ax.set_ylabel('gdp')
# Out:
# Text(0, 0.5, 'gdp')

# %% [markdown]
# ## Visualization

# %%
# create a figure and axis
fig, ax = plt.subplots()

# scatter the population and year
ax.scatter(df['year'], df['population'])

# set a title and labels
ax.set_title('Population over the Years')
ax.set_xlabel('year')
ax.set_ylabel('population')
# Out:
# Text(0, 0.5, 'population')

# %% [markdown]
# From the graph above, we can see that there is an upward trend of the population of Bangladesh over the years.

# %%
# create a figure and axis
fig, ax = plt.subplots()

# scatter the export and year
ax.scatter(df['year'], df['export'])

# set a title and labels
ax.set_title('Export over the Years')
ax.set_xlabel('year')
ax.set_ylabel('export')
# Out:
# Text(0, 0.5, 'export')

# %%
# create a figure and axis
fig, ax = plt.subplots()

# scatter the gdp and export
ax.scatter(df['gdp'], df['export'])

# set a title and labels
ax.set_title('GDP & Export')
ax.set_xlabel('GDP')
ax.set_ylabel('export')
# Out:
# Text(0, 0.5, 'export')

# %% [markdown]
# ## Reference:
# Worldbank. (2021, October 3). Retrieved from data.worldbank.org: https://databank.worldbank.org/source/world-development-indicators/preview/on
